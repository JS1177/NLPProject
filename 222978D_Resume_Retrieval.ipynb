# %%
import numpy
import pandas
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score
import random
# Out:
# C:\Users\JS\AppData\Local\Temp\ipykernel_20056\3803341183.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
random.seed(42)

# %%
from preprocessing_NLP import pipeline

resumes_df = pipeline('UpdatedResumeDataSet_T1_7.csv', feature_name='Resume')
resumes_df
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\JS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\JS\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\JS\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\JS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\JS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#               Category                                             Resume
# 0         Data Science  qwtnrvduof education detail may 2013 may 2017 ...
# 1         Data Science  qwtnrvduof area interest deep learn control sy...
# 2         Data Science  skill r python sap hana tableau sap hana sql s...
# 3         Data Science  education detail mca ymcaust faridabad haryana...
# 4         Data Science  skill c basic iot python matlab data science m...
# ...                ...                                                ...
# 873            Testing  skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 874            Testing  good logical analytical skill positive attitud...
# 878            Testing  personal skill quick learner eagerness learn n...
# 1540   DevOps Engineer  core skill project program management agile sc...
# 7135  Business Analyst  education detail february 2006 february 2006 t...
#
# [188 rows x 2 columns]

# %%
resumes_df = resumes_df.reset_index(drop=True)
test_df = resumes_df.sample(32, random_state=42)
train_df = resumes_df.drop(test_df.index)

test_df = test_df.reset_index(drop=True)
train_df = train_df.reset_index(drop=True)

# %% [markdown]
# Fit Vectorizer using train_df

# %%
resumes = train_df.Resume.to_numpy()
resumes
# Out:
# array(['qwtnrvduof education detail may 2013 may 2017 bbntgbqlmkke uit rgpv data scientist data scientist matelabs skill detail python exprience le 1 year month statsmodels exprience 12 month aws exprience less 1 year month machine learn exprience le 1 year month sklearn exprience le 1 year month scipy exprience le 1 year month keras exprience less 1 year monthscompany detail company matelabs description ml platform business professional dummy enthusiastsckekjofvwq 60 koramangala 5th block achievement task behind sukh sagar bengaluru india develop deployed auto preprocessing step machine learn mainly miss value treatment outlier detection encode scaling feature selection dimensionality reductionqunsobcudt deploy automated classification regression modelrynoolxhuv b4600b146 reasearch deploy time series forecast model arima sarimax holt winter prophetiqmadshiyn work meta feature extract problemiszogerzlf implement state art research paper outlier detection mixed attribute company matelabs description',
#        'qwtnrvduof area interest deep learn control system design program python electric machinery web development analytics technical activity q hindustan aeronautics limit bangalore 4 week guidance mrbntgbqlmkk satish senior engineer hangar mirage 2000 fighter aircraft technical skill program matlab python java labview python webframework django flask ltspice intermediate language mipower intermediate github gitbash jupyter notebook xampp mysql basic python software package interpreter anaconda python2 python3 pycharm java ide eclipse operate system windows ubuntu debian kali linux education detail january 2019 bckekjofvwqtechqunsobcudt electrical electronics engineering manipal institute technology january 2015 deeksha center january 2013 little flower public school august 2000 manipal academy higher data science data science electrical enthusiast skill detail data analysis exprience le 1 year month excel exprience le 1 year month machine learn exprience le 1 year month mathematics exprience less 1 year month python exprience le 1 year month matlab exprience le 1 year month electrical engineering exprience less 1 year month sql exprience le 1 year monthscompany detail company themathcompany description currently work casino base operator name disclose macaurynoolxhuvi need segment customer visit property base value patron bring companysajhwmuxoobasically prove segmentation do much well way current system proper number back upiqmadshiynhenceforth implement target marketing strategy attract customer add value businessiszogerzlf',
#        'skill r python sap hana tableau sap hana sql sap hana pal m sql sap lumira c linear program data model advance analytics scm analytics retail analytics social medium analytics nlp education detail january 2017 january 2018 pgdm business analytics great lake institute management illinois institute technology january 2013 bachelor engineering electronics communication bengaluru karnataka new horizon college engineering bangalore visvesvaraya technological university data science consultant consultant deloitte usi skill detail linear program exprience 6 month retail exprience 6 month retail marketing exprience 6 month scm exprience 6 month sql exprience less 1 year month deep learn exprience le 1 year month machine learn exprience le 1 year month python exprience le 1 year month r exprience le 1 year monthscompany detail company deloitte usi description project involve analyse historic deal come insight optimize future dealsbntgbqlmkk role give raw data carry end end analysis present insight clientckekjofvwq key responsibility extract data client system across geographiesqunsobcudt understand build report tableaurynoolxhuv infer meaningful insight optimize price find process blockadessajhwmuxoo technical environment r tableauiqmadshiyn industry cross industry service area cross industry product project name handwrite recognition consultant 3 monthsiszogerzlf project involve take handwritten image convert digital text image object detection sentence creationbrbegnceae role develop sentence correction functionality key responsibility gather data large enough capture english word train lstm model word technical environment python industry finance service area financial service bi development project name swift consultant 8 month project develop analytics infrastructure top sap 4 would user view financial report respective department report also include forecasting expense role lead offshore team key responsibility design develop data model report develop etl data flow validate various report technical environment sap hana tableau sap ao industry healthcare analytics service area life science product development project name clinical healthcare system consultant 2 month project develop analytics infrastructure top argus would allow user query faster provide advance analytics capability role involve design deploy phase perform lot data restructure build model insight key responsibility design develop data model report develop deploy analytical model validate various report technical environment data model sap hana tableau nlp industry fmcg service area trade promotion project name consumption base plan flower food consultant 8 month project involve set crm cbp module role involve key data decomposition activity set base future year forecast course project develop various model carry key performance improvement key responsibility design develop hana model decomposition develop data flow forecast develop various view report customer sale fund validate various report bobj technical environment data model sap hana bobj time series forecast internal initiative industry fmcg customer segmentation rfm analysis consultant 3 month initiative involved set hana python interface advance analytics python course successfully segment data five core segment use k mean carry rfm analysis python also develop algorithm categorize new customer define bucket technical environment anaconda3 python3 6 hana sps12 industry telecom invoice state detection consultant 1 month initiative reduce manual effort verify close open invoice manually involve development decision tree classify open close invoice enable effort reduction 60 technical environment r sap pal sap hana sps12 accenture experience industry analytics cross industry process analytics sap senior developer 19 month accenture solution pvt ltd india project involve development sap analytics tool process analytics ipa role develop database object data model provide operational insight client role ...
#        'education detail mca ymcaust faridabad haryana data science internship skill detail data structure exprience less 1 year month c exprience le 1 year month data analysis exprience le 1 year month python exprience le 1 year month core java exprience less 1 year month database management exprience less 1 year monthscompany detail company itechpower description',
#        'skill c basic iot python matlab data science machine learn html microsoft word microsoft excel microsoft powerpointbntgbqlmkk recognition academic secure first place bckekjofvwqtechqunsobcudteducation detail august 2014 may 2018 brynoolxhuvtechsajhwmuxoo ghatkesar andhra pradesh aurora scientific technological institute june 2012 may 2014 secondary education warangal telangana sr junior college data science skill detail m office exprience less 1 year month c exprience le 1 year month machine learn exprience le 1 year month data science exprience less 1 year month matlab exprience le 1 year monthscompany detail company description',
#        'education detail bbntgbqlmkktech rayat bahra institute engineering biotechnology data science data science skill detail numpy exprience less 1 year month machine learn exprience le 1 year month tensorflow exprience le 1 year month scikit exprience le 1 year month python exprience le 1 year month gcp exprience le 1 year month pandas exprience le 1 year month neural network exprience less 1 year monthscompany detail company wipro description bhawana aggarwal e mail bhawanackekjofvwqchd gmailqunsobcudtcom phone 09876971076 vversatile high energy professional target challenge assignment machine profile summary professional knowledge experience 2 year wipro technology machine learn deep learning data science python software developmentrynoolxhuv skilled manage end end development software product project inception requirement spec plan design implementation configuration documentationsajhwmuxoo knowledge python machine learn deep learning data science algorithm neural network nlp gcpiqmadshiyn knowledge python library like numpy panda seaborn matplotlib cufflinksiszogerzlf knowledge different algorithm machine learn like knn decision tree bias variance trade support vector machine svm logistic regression neural networksbrbegnceae knowledge unsupervised supervised reinforcement data program experience relational platform like mysql oracle knowledge program language like c java experience cloud base environment like google cloud work different operate system like linux ubuntu window good interpersonal communication skill problem solve skill ability think laterally think medium term long term perspective flexibility open attitude change ability create define framework strong emphasis code reusability technical skill program language python c library seaborn numpy panda cufflink matplotlib algorithm knn decision tree linear regression logistic regression neural network k mean cluster tensorflow svm database sql oracle operate system linux window development environment netbeans notebooks sublime ticketing tool service remedy education ug education b tech computer science rayat bahra institute engineering biotechnology pass 78 4 2016 school xii 2012 moti ram arya sr secondary school pass 78 4 x 2010 valley public school pass 9 4 cgpa work experince title wipro neural intelligence platform team size 5 brief wipro neural intelligence platform harness power automation artificial intelligence technology natural language processing nlp cognitive machine learn analytics platform comprise three layer data engagement platform easily access manage multiple structure unstructured data source intent assessment reason engine include sentiment predictive analytics deep machine learn engine sense act learn time project entail automating response user query earliest monster bot use power deep machine learn nlp handle query user see query answer quickly like alll1 activity eliminate entity extractor involve text extraction nlp fetch important information text like date name place contact number etc involve regex bluemix nlu api machine learn use tensor flow learn new entity classifier involve classification class train dataset predicting output use sklearn classifier mnb svm sgd classifier sgd optimization map user query best suit response make system efficient ner deep learning ner model train extract entity text entity like role skill organization extract raw text rnn lstm bidirectional model train extract entity use kera tensorflow framework project title diabetes detection brief develop software detect whether person suffer diabetes get third prize training certification title python training machine learn data science deep learning organization udemy coursera machine learn deep learn personal profile father name mr tirlok aggarwal language know english hindi marital status single date birth gender 1993 12 20 yyyy mm dd f company wipro description develop program python company wipro description title wipro neural intelligence platform team ...
#        'personal skill ability quickly grasp technical aspect willingness learn high energy level result orientedbntgbqlmkk education detail january 2018 master engineering computer technology application bhopal madhya pradesh truba institute engineering information technology january 2010 bckekjofvwqequnsobcudt computer science bhopal madhya pradesh rkdf institute science technology college engineering january 2006 polytechnic information technology vidisha madhya pradesh sati engineering college vidisha january 2003 mrynoolxhuvtech thesis detail bmch school ganj basoda data science six month experience data sciencesajhwmuxoo key skill experience machine learn deep leaning nlp python sql web scrap good knowledge computer subject ability update skill detail experience machine learn deep learning nlp python sql web crawl html cssiqmadshiyn exprience less 1 year monthscompany detail company rntiszogerzlfai technology solution description text classification use machine learn algorithm pythonbrbegnceae practical knowledge deep learning algorithm recurrent neural network rnn develop custom data model algorithms apply dataset experience python package like panda scikit learn tensor flow numpy matplotliv nltk comfort sql mysql sentiment analysis apply leave dataset use classification technique like tf idf lsa cosine similarity use machine learn algorithm web crawl use selenium web driver beautiful soup python company life insurance corporation india bhopal description explain policy feature benefit update knowledge life insurance product share customer',
#        'expertise data quantitative analysis decision analytics predictive model data drive personalization kpi dashboard big data query interpretation data mining visualization tool machine learn algorithm business intelligence bi research report forecast education detail pgp data science mumbai maharashtra aegis school data science business bbntgbqlmkkeckekjofvwq electronics communication electronics communication indore madhya pradesh y ips academy data scientist data scientist pr canada skill detail algorithms exprience 6 month bi exprience 6 month business intelligence exprience 6 month machine learn exprience 24 month visualization exprience 24 month spark exprience 24 month python exprience 36 month tableau exprience 36 month data analysis exprience 24 monthscompany detail company aegis school data science business description mostly work industry project provide solution along teach appointment teach undergraduate graduate level course spark machine learning adjunct faculty member aegis school data science mumbai 2017 present company aegis school data business description data science intern nov 2015 jan 2016 furnish executive leadership team insight analytics report recommendation enable effective strategic planning across business unit distribution channel product linesqunsobcudt chat bot use aws lex tensor flow python goal project create chat bot academic institution university handle query relate course offer instituterynoolxhuv objective task reduce human effort well reduce man make errorssajhwmuxoo even company handle client 24x7iqmadshiyn case company academic institution client participant studentsiszogerzlf web scrap use selenium web driver python task scrap data online message portal text format find pattern form itbrbegnceae data visualization data insight hadoop eco system hive pyspark qliksense goal project build business solution internet service provider company like handle data generate per day basis visualize data find usage pattern form generate report image base fraud detection microsoft face api pyspark open cv main goal project recognize similarity face give database image face recognition recognize special face set different face face extract compare database image image recognize person already apply loan somewhere else hide identity go prevent fraud initial stage churn analysis internet service provider r python machine learn hadoop objective identify customer likely churn give period time pretend customer give incentive offer sentiment analysis python nlp apache spark service ibm bluemix project highly emphasis tweet twitter data take mobile network service provider sentiment analysis analyze whether expressed opinion positive negative neutral capture emotion tweet comparative analysis quantifiable result mentor 7 12 data science enthusiast year since go graduate school data science business analytics review evaluate 20 40 research paper data science one largest data science conference call data science congress aegis school business mumbai head solution provide organization call data science deliver aegis school data science mumbai manage 4 5 live project use data science technique work social cause help data science social good committee team develop product call let find miss child help society company ibm india pvt ltd description mostly work blumix ibm watson data science',
#        'education detail may 2013 may 2017 bbntgbqlmkke uit rgpv data scientist data scientist matelabs skill detail python exprience le 1 year month statsmodels exprience 12 month aws exprience less 1 year month machine learn exprience le 1 year month sklearn exprience le 1 year month scipy exprience le 1 year month keras exprience less 1 year monthscompany detail company matelabs description ml platform business professional dummy enthusiastsckekjofvwq 60 koramangala 5th block achievement task behind sukh sagar bengaluru india develop deployed auto preprocessing step machine learn mainly miss value treatment outlier detection encode scaling feature selection dimensionality reductionqunsobcudt deploy automated classification regression modelrynoolxhuv b4600b146 reasearch deploy time series forecast model arima sarimax holt winter prophetiqmadshiyn work meta feature extract problemiszogerzlf implement state art research paper outlier detection mixed attribute company matelabs description',
#        'area interest deep learn control system design program python electric machinery web development analytics technical activity q hindustan aeronautics limit bangalore 4 week guidance mrbntgbqlmkk satish senior engineer hangar mirage 2000 fighter aircraft technical skill program matlab python java labview python webframework django flask ltspice intermediate language mipower intermediate github gitbash jupyter notebook xampp mysql basic python software package interpreter anaconda python2 python3 pycharm java ide eclipse operate system windows ubuntu debian kali linux education detail january 2019 bckekjofvwqtechqunsobcudt electrical electronics engineering manipal institute technology january 2015 deeksha center january 2013 little flower public school august 2000 manipal academy higher data science data science electrical enthusiast skill detail data analysis exprience le 1 year month excel exprience le 1 year month machine learn exprience le 1 year month mathematics exprience less 1 year month python exprience le 1 year month matlab exprience le 1 year month electrical engineering exprience less 1 year month sql exprience le 1 year monthscompany detail company themathcompany description currently work casino base operator name disclose macaurynoolxhuvi need segment customer visit property base value patron bring companysajhwmuxoobasically prove segmentation do much well way current system proper number back upiqmadshiynhenceforth implement target marketing strategy attract customer add value businessiszogerzlf',
#        'qwtnrvduof ibntgbqlmkktckekjofvwq skill windows xp m office word excel look ups pivot table basic function power point saral payment package payroll software internet applicationseducation detail january 2006 bachelor hospitality management international hospitality management queen margaret university edinburg january 2006 diploma hotel management international institute hotel management hr skill detail hr management exprience less 1 year monthscompany detail company atri developer description hr payroll statutory compliance performance management company description employee relation administration create industry specific policy procedure form format letter checklist etc payroll management salary restructuring process payroll 600 employeesqunsobcudt validation input attendance leave salary start salary processrynoolxhuv processing accurate error free salary employeessajhwmuxoo responsible compensation benefit administrationiqmadshiyn coordinate account team salary processingiszogerzlf attendance leave record management assure prompt satisfactory resolution payroll related query employeesbrbegnceae statutory compliance management manage various statutory compliance requirement pf esic pt gratuity tds etc calculation deduction payment return file generate statutory report like form 16 form 24q conducting session employee statutory policy procedure compliance relate topic shop commercial establishment act e payment gratuity act 1972 recruitment selection handle recruitment like job post naukri portal coordination create annual manpower plan budget screen schedule preliminary interview arrange employee orientation handle join formality salary account open formality performance management end end facilitation pm start create job description appraisal form disbursement letter kra set mid year review annual review handle appraisal activity 360 degree training development conduct train need analysis arrange various train session employee engagement employee welfare creation deployment sale reward recognition scheme periodic interactive session like monthly birthday celebration annual day diwali dhamaka offsite etc work saral payment package payroll software well excel assist md hr work offer suggestion answer employee query payroll compliance relate issue benefit insurance medical reimbursement full final settlement resign employee',
#        'qwtnrvduof education detail ba mumbai university hr skill detail hr operation exprience less 1 year monthscompany detail company mumbai monorail description',
#        'education detail june 2012 may 2015 bbntgbqlmkka economics chennai tamil nadu sdnbvc hr skill detail company detail company anything solution description hr',
#        'key skill computerize accounting tally sincere hard work management accounting income tax good communication leadership two four wheeler drive license internet ecommerce management computer skills c language web program tally dbms education detail june 2017 june 2019 mba finance hr india mlrit june 2014 june 2017 bcom computer hyderabad telangana osmania university june 2012 april 2014 inter mec india srimedhav hr nani skill detail account exprience 6 month database management system exprience 6 month dbms exprience 6 month management accounting exprience 6 month ecommerce exprience 6 monthscompany detail company valuelabs description give rrf form require dlt hand rlt scrum master take form rlt scrum master give form trainee work requirement till candidate receive offer company',
#        'software skills general computer proficiency program langages know c c java web programming tool software know matlabbntgbqlmkk dbms key strength posse good communication analytic skillsckekjofvwq positive thinkingqunsobcudt sincere hard work honesty responsibilityrynoolxhuv enthusiastic learn new skill take new taskssajhwmuxoo self motivatediqmadshiyn ready accept challenge education detail january 2014 january 2017 computer science engineering computer science engineering adichunchanagiri institute technology chikmagalur hr skill detail database management system exprience 6 month dbms exprience 6 month java exprience 6 month matlab exprience 6 monthscompany detail company truly description jayashree h iszogerzlfk',
#        'technical skill typewrite tora spsseducation detail january 2017 mba chidambaram tamil nadu sn college engineering january 2014 hsc sav higher secondary school mba sn college engineering sslc finance kamaraj matriculation school hr skill detail human resource finance exprience less 1 year monthscompany detail company description',
#        'ibntgbqlmkktckekjofvwq skill windows xp m office word excel look ups pivot table basic function power point saral payment package payroll software internet applicationseducation detail january 2006 bachelor hospitality management international hospitality management queen margaret university edinburg january 2006 diploma hotel management international institute hotel management hr skill detail hr management exprience less 1 year monthscompany detail company atri developer description hr payroll statutory compliance performance management company description employee relation administration create industry specific policy procedure form format letter checklist etc payroll management salary restructuring process payroll 600 employeesqunsobcudt validation input attendance leave salary start salary processrynoolxhuv processing accurate error free salary employeessajhwmuxoo responsible compensation benefit administrationiqmadshiyn coordinate account team salary processingiszogerzlf attendance leave record management assure prompt satisfactory resolution payroll related query employeesbrbegnceae statutory compliance management manage various statutory compliance requirement pf esic pt gratuity tds etc calculation deduction payment return file generate statutory report like form 16 form 24q conducting session employee statutory policy procedure compliance relate topic shop commercial establishment act e payment gratuity act 1972 recruitment selection handle recruitment like job post naukri portal coordination create annual manpower plan budget screen schedule preliminary interview arrange employee orientation handle join formality salary account open formality performance management end end facilitation pm start create job description appraisal form disbursement letter kra set mid year review annual review handle appraisal activity 360 degree training development conduct train need analysis arrange various train session employee engagement employee welfare creation deployment sale reward recognition scheme periodic interactive session like monthly birthday celebration annual day diwali dhamaka offsite etc work saral payment package payroll software well excel assist md hr work offer suggestion answer employee query payroll compliance relate issue benefit insurance medical reimbursement full final settlement resign employee',
#        'education detail ba mumbai university hr skill detail hr operation exprience less 1 year monthscompany detail company mumbai monorail description',
#        'education detail llbbntgbqlmkk dibrugarh university advocate skill detail legalckekjofvwq exprience less 1 year monthscompany detail company legalqunsobcudt description advocate',
#        'education detail november 2016 january 2019 llm master law hyderabad telangana sultan ul uloom college law september 2011 may 2016 babntgbqlmkkllb bachelor law hyderabad telangana osmania university pg college law advocate experience litigation recently acquire master degree law skill detail microsoft word exprience less 1 year month litigation exprience less 1 year month legal research exprience less 1 year month contract exprience less 1 year month internet savvy exprience less 1 year month draft exprience le 1 year monthscompany detail company lrc office description work senior advocate l ravichander high court telanganackekjofvwq experience draft legal correspondence',
#        'skill know english native speaker ielts overall 8 listen 8 read 8 write 7 speak 8bntgbqlmkk5 hindi bilingual proficiency punjabi native speakerckekjofvwq able communicate clearly concisely people diverse background level authorityqunsobcudt exceptional knowledge administrative procedure evidence rule trialsrynoolxhuv maintain professional attitude peer co worker client timessajhwmuxoo focused driven always meet deadline pretrial procedure trial appellate briefing effectively utilize resourcesiqmadshiyn microsoft certify system engineer 2008 much competent windows word processing software education detail july 2009 may 2012 bachelor law bikaner rajasthan maharaja ganga singh university august 2008 november 2008 microsoft certify system engineer network chandigarh july 2005 april 2008 bachelor science bio informatics chandigarh chandigarh panjab university advocate newcomer indian advocate skill detail administration exprience 72 month legal research exprience 72 month microsoft office exprience 72 month draft exprience 72 monthscompany detail company district court description key feature license advocate practice 16 aug 2012 bar council punjab haryana chandigarh iszogerzlf admit practice district court mansa since 18 aug 2012brbegnceae successfully pass india bar examination aibe conduct bar council india bci september 2013 lead sole counsel plaintiff respondent number criminal civil trial since 2012 prepare prosecute conclusion either trial settlement number claim case involve personal injury death case work panel district legal service authority mansa run supervision national legal service authority india former co opt member administrative committee punjab former joint secretary district bar association mansa 2017 18 job duty advice client legal right matter related law plead client case include various international company court law forums tribunal board research legal precedent gather evidence trial criminal injury death compensation claim others draw legal document bail petition appeal divorce contract etc negotiate settlement civil dispute act mediator conciliator local commissioner arbitrator per court order manage private practice 6 year include aspect administration management function control cost achieve objective relate practice law',
#        'qualification introduction computer extraeducation detail january 2001 january 2003 master law chennai tamil nadu drbntgbqlmkkambedkar law university january 1998 january 2001 bachelor law chennai tamil nadu drckekjofvwq ambedkar law university january 1995 january 1998 bachelor english literature tirunelveli tamil nadu manonmaniam sundaranar university advocate advocate skill detail company detail company practice description high court judicature madras india city civil court chennai debt recovery tribunal chennai consumer forum chennai labour court small cause court rent control court legal advisor christian institute management chennai 2016 legal advisor ruah church chennai nessa trust till 2018',
#        'skill natural language proficient english hindi marathibntgbqlmkk computer skills proficient m office internet operationckekjofvwqeducation detail january 2015 january 2018 llb law mumbai maharashtra mumbai university january 2015 bqunsobcudtmrynoolxhuvm mumbai maharashtra ssajhwmuxookiqmadshiynsomaiya college mumbai university hiszogerzlfsbrbegnceaec asmita girl junior college maharashtra board c vidya bhawan maharashtra board advocate llb student journalist skill detail company detail company criminal lawyer law firm description',
#        'good grasping quality skillful work education detail march 2013 march 2018 bbntgbqlmkk ackekjofvwq llqunsobcudt brynoolxhuv law solapur maharashtra solapur university advocate skill detail good knowledge type well many activity exprience less 1 year monthscompany detail company district session court solapur description forward think individual refine interpersonal multitasking skillssajhwmuxoo look join progressive organization provide assistance legal workiqmadshiyn company district session court solapur description provide legal assistance legal work',
#        'hard work quick learnereducation detail june 2014 may 2017 llb law mumbai maharashtra mumbai university january 2014 bbntgbqlmkkcom commerce mumbai maharashtra mumbai university january 2011 hsc maharashtra board january 2009 ssc maharashtra board advocate skill detail company detail company vidishtra description',
#        'technical qualification windows msbntgbqlmkk officeeducation detail llckekjofvwqb guwahati assam university law college guwahati university bqunsobcudtsc jagiroad assam jagiroad college morigaon college advocate advocate gauhati high court skill detail company detail company gauhati high court description gauhati high court subordinate court tribunal statutory body guwahati 2008rynoolxhuv numerous experience civil criminal case case consumer forumsajhwmuxoo handle good number civil well criminal matter district session judge court judge court ciqmadshiynjiszogerzlfmbrbegnceae court consumer forum also high court work executive legal hindustan paper corporation limit govt india enterprise nagaon paper mill since jan 2012 strength adaptability penchant adapt condition level environment accordance requirement give situation interpersonal extrovert core prefer interact people walk life vary stratum society ability quickly establish rapport others team work enjoy part group achieve combine goal role responsibility hpc ltd assist briefing counsel matter relate nagaon paper mill cachar paper mill also nagaland pulp paper corporation ltd task legal vet nib nit term condition etc provide legal view protect interest corporation assist formulation draft disciplinary matter liaisoning local body also forums',
#        'good communication skill quick learner keen find solutionseducation detail mba masibqtserxdybsvdazdwkblqbsqtzuxmnnfuivuvt',
#        'operate system windows xp vista 07education detail january 2018 mbntgbqlmkkfckekjofvwqa paint nagpur maharashtra nagpur university january 2016 bqunsobcudtfrynoolxhuvasajhwmuxoo paint nagpur maharashtra nagpur university january 2012 diploma art maharashtra state board january 2010 hiqmadshiynsiszogerzlfcbrbegnceae maharashtra state board january 2008 c maharashtra state board fine art lecturer skill detail ms cit exprience 96 monthscompany detail company shubhankan fine art college indore description job lecturer shubhankan fine art college indore nov 2018 artist complete atd bfa mfa paint search job faculty area comfort place improve knowledge experience field company description experience class paint rangoli draw summer class etc health physical disability orthopedically',
#        'additional qualification april 2000 web design course average computer skillseducation detail january 2000 january 2001 bachelor art sociology mumbai maharashtra mumbai university january 1998 january 2000 bachelor art sociology sophia college january 1997 january 1998 hbntgbqlmkksckekjofvwqcqunsobcudt sophia college january 1995 january 1996 srynoolxhuvssajhwmuxoociqmadshiyn stiszogerzlf teresa convent high school head business development art head business development art skill detail company detail company british council description responsibility strategic oversight responsibility programme perform art music theatre dance cultural sectorsbrbegnceae lead conception oversight specific large scale programme within overall art programme represent british council external event india act deputy director art require oversee manage resource deliver compel communication applicant convey british council grant like charles wallace india trust young creative entrepreneur chevening clore scholarship program time excellence shortlist interview potential applicant exist relevant grant fellowship oversee diverse range proposal progress report related project ensure effective timely identification communication program progress lead team six project manager across country manage performance team responsible execute art project partnership build work expertise within geographic region ensure art insight knowledge available require managing relation exist partner develop relationship target new partner key government official ensure market insight business development opportunity build plan new programme primary strategic responsibility marketing art program india ensure program build reputation attractive potential partner partnership marketing communication team company british council description cultural relation organization create international opportunity people uk country build trust worldwide office six continent 100 country bring international opportunity life every day year work million people connect united kingdom share culture uk attractive asset english art education 80 year experience company british council description responsibility lead strategic development british council work music sector india sri lanka region building maintain strong international partnership across sector india sri lanka uk develop strong external partnership lead significant external investment bc activity enable delivery ambitious programme music sector activity event thus strengthen cultural relationship india sri lanka uk lead implementation music programme within india sri lanka along detail project plan liaison colleague india sri lanka uk proactive management budget timelines project ensure systematic evaluation project include develop effective system process capture quantitative qualitative information effectiveness project longer term impact management team across india sri lanka contribute recruitment development mentor staff company british council description responsibility plan organize logistics related event building performer artist personnel market performance event social medium direct mail advertising use website produce poster publicity leaflet attract medium coverage planning manage budget program book performance event include arrangement tour india development new project initiatives consultation art professional key stakeholder e g local authority local government community venue director regional partner take responsibility operational office management issue venue accessibility health safety issue implement maintain office information system provide administration support manager director ensure corporate legal requirement comply report head unit company british council description responsibility develop new specific new project initiative music film visual art sector consultation council key stakeholder plan manage budget support marketing performance event social medium direct mail advertising use website produc ...
#        'education detail january 2017 rachana sansad school interior deign january 2013 holy family high school master commerce marketing mumbai maharashtra university mumbai draw art craft teacher draw art craft teacher ghatkopar ymca skill detail company detail company ghatkopar ymca description 3 yearsbntgbqlmkk work jungle cub gym co ordinator 1 yearckekjofvwq',
#        'skill course skill name board year pass grade intermediate grade draw art examination committee 2011 b examination maharashtra state academic programme detail national service scheme camp sponsor government india ministry youth affair sport new delhi north maharashtra university jalgaonbntgbqlmkk strength ability learn mistakesckekjofvwq honesty ready accept challenge responsibilitiesqunsobcudt quick learning adaptability confidencerynoolxhuv declaration 201 faithfully pia sajhwmuxooiqmadshiyn iszogerzlf brbegnceae jetalal hiralal gorbanjara education detail may 2010 hsc nashik maharashtra state board june 2008 ssc nashik maharashtra state board asst professor asst professor skill detail company detail company kisan art description total work experience month sr name organization college designation work period total experience month 1 kisan art commerce science asst professor 20 07 2015 31 05 2016 10 month sr college parola dist jalgaon political sci maharashtra company bahadarpur tai parola dist description',
#        'good communication skill quick learner keen find solutionseducation detail mba market international business management pune maharashtra pune university b tech tech nagpur maharashtra rtm nagpur university gbntgbqlmkkmckekjofvwq art commerce science gqunsobcudtmrynoolxhuv art commerce science skill detail company detail company samarth college description engineering 30 7 210 5 college campus vj college pharmacy 10 day workshop 10 gsajhwmuxoomiqmadshiyn art commerce science 6 soft skill 6 day workshop 6 college personality giszogerzlfmbrbegnceae institute agricultural 7 6 day workshop 6 development diploma 8 soft skill samarth college polytechnic 20 day workshop 20 total 350 work experience corporate sr topic company day total hr 1 presentation skill team elringklinger automotives pvt 1 day 8 building workshop ltd ranjangaon pune 2 negotiation skill kubler automation pvt ltd 2 day 16 communication skill chakan pune 3 business communication finanza home loan pimple 3 day 21 stress management saudagar pune 4 team building verbal sharvari product pvt ltd 2 day 16 communication junner pune 7 day 5 entrepreneurship agriculture research centre workshop 168 development narayangaon pune 8 batch total 229 adjoin skill work knowledge window operate system m office communicate well english hindi marathi organize participated event like gather teacher day fashion show various science exhibition college',
#        'education detail august 2018 january 2021 entermediate math mumbai maharashtra sunbeam academy samne ghat varanasi martial art fitness job skill detail company detail company sport authority description 2nd dan black belt karate martial art search personal trainer job fitnessbntgbqlmkk 3 gold medal national karate championshipckekjofvwq 7 gold medal state karate championshipqunsobcudt 3 time best player year uttar pradesh award rynoolxhuvsajhwmuxoo represent india select world karate championship hold croatia europeiqmadshiyn',
#        'technical skill web technology angular j html5 css3 sas bootstrap jquery javascript softkehdwhplubufjtgzwoinlegenlzyuqmiizpocff',
#        'education detail january 2016 bbntgbqlmkkscckekjofvwq information technology mumbai maharashtra university mumbai january 2012 hsc allahabad uttar pradesh allahabad university january 2010 ssc dot net allahabad uttar pradesh allahabad university web designer developer trainer web designer developer skill detail web design exprience 12 month php exprience 12 monthscompany detail company nettech india description workingqunsobcudt salary 12k personal interest listen music surf net watch movie playing cricketrynoolxhuv company epi center academy description workingsajhwmuxoo salary contract base company aptech charni road description salary contract base',
#        'skill languages c basic java basic web technology html5 css3 bootstrap javascript jquery corel draw photoshop illustrator databases mysql5bntgbqlmkk0 ide tool sublime text notepad operate system windows xp window 7education detail september 2015 bachelor engineer information technology nagpur maharashtra nagpur university may 2011 hsc secondary higher secondary state board secondary june 2009 ssc secondary higher secondary maharashtra state board secondary web graphic designer web graphic designer virtuous medium point pune skill detail bootstrap exprience 24 month html5 exprience 24 month javascript exprience 24 month jquery exprience 24 month corel draw exprience 24 month adobe photoshop exprience 24 month adobe illustrator exprience 12 month css3 exprience 24 monthscompany detail company virtuous medium point description company cnc web world description internship program e sense solution pvtckekjofvwqltdqunsobcudt nagpur web design developementrynoolxhuv present project competition innovesta 15 priyadarshini indira gandhi college engineering nagpursajhwmuxoo present national level paper presentation tech wave 2015 siqmadshiynriszogerzlfmbrbegnceaec e nagpur company e sense solution pvt ltd description key result area design website solution study information need confer user study system flow data usage work process understood process requirement provide use case business functional technical requirement interact user requirement gathering prepared functional specification low level design document participate software development life cycle sdlc agile methodology right requirement analysis perform detailed design module along implementation documentation integrate software module develop team member highlight develop various module per customer requirement identify fixed number bug related code database connectivity ui defect analyze modify exist code incorporate number change application user requirement write new code require cod implemented integrated complex program use technology html5 css3 javascript jquery bootstrap good command graphic design effective idea project www nitka com nagpur united corporation admin mintmetrix com tagline video admin smartbadge admin project use technology like html5 css3 bootstrap javascript jquery text editor sublime text www shreekiaspack co www 3staragroproducts com www luckystationery co use technology like html5 css3 bootstrap javascript text editor notepad design various logo brochure advertise banner visit card pamphlet hoarding etc b e final year project major project title web base disease diagnosis expert system duration 1 year description project provide website doctor give online consultation particular disease system give better suggestion health problem mini project development shop management system develop c curriculum extra curriculum activity company face description co ordinator project competition',
#        'skill knowledge software computer auto cad include diploma academic syllabus mscit cnc program fanuc series mill strength strong dedication towards workbntgbqlmkk quick learnerckekjofvwq positive think self confidencequnsobcudt honest discipline hardworkingrynoolxhuv industrial experience 10 day industrial training nagpur agro component hingna road nagpursajhwmuxoo 10 day industrial training metal fab high tech pvtiqmadshiyn ltd hingna road nagpuriszogerzlf extra criculum activity education detail bbrbegnceaee rtmnu mechanical engineering skill detail auto cad exprience 6 month automotive exprience 6 month automotive cnc exprience 6 month cad exprience 6 month cnc exprience 6 monthscompany detail company tata motor adani maruti suzuki jet airways air india description 1 student mechanical engineering final year fresher experiance industry 2 3 rd year industrial training program conduct 10 day train experiance industry 3 5 th semister 10 day work nagpur agro component work machine cnc machine see industry 4 6 th semister another training program metal fab company company description english hindi marathi participate jsw urja project competition 2017 2018 machine assembly disassembly function part 1 week final year project design nd fabrication pneumatic punching machine paddle operate sugarcane juicer machine diploma engineering',
#        'education detail january 2018 bachelor engineering engineering mumbai maharashtra mgm college engineering diploma mechanical pune maharashtra mit president mechanical engineering student association president mechanical engineering student association skill detail company detail company full throttle description conduct iit bombaybntgbqlmkk work president mechanical engineering student association mesa mit puneckekjofvwq company rqunsobcudtc car race stepcone description paper project contest exhibition conduct gmr instiute technologyrynoolxhuv',
# ...
#        'hobby play chess solve rubik cube watch series language english hindi marathi education detail january 2014 january 2017 bachelor degree information technology first class pune maharashtra jspm jayawantrao sawant college engineering january 2010 january 2014 diploma information technology first class nashik maharashtra kbntgbqlmkk kckekjofvwq wagh polytechnic january 2010 ssc first class nashik maharashtra new era english school blockchain developer blockchain developer corpcloud global service pvtqunsobcudt ltd skill detail blockchain exprience 6 month smart contract exprience 6 month dapps exprience 6 month mean stack exprience 12 monthscompany detail company corpcloud global service pvtrynoolxhuv ltdsajhwmuxoo description work productively team identify requirement propose idea enhance productiqmadshiyn develop manage user blockchain account wallet transactionsiszogerzlf regularly monitor smooth execution blockchain transaction wallet function along identify correct possible errorsbrbegnceae write smart contract api document company corpcloud global service pvt ltd description identify complex bug system resolve implement updated application module direction senior effectively cod require change alteration check repository use bit bucket perform code check in check out regularly work api',
#        'computer proficiency basic m office powerpoint word outlook excel language know basic c cpp javabntgbqlmkk basic network basic command linux project detail minor project detail title applocker androidckekjofvwq project area android applicationqunsobcudt description applocker provide protection system application well third party application instal android devicesrynoolxhuv password protection provide help pattern volume keyssajhwmuxoo hence extra measure privacy acquirediqmadshiyn major project detail title online complaint system cyber crimesiszogerzlf project area android application description online complaint system cyber crime android application use person lodge complaint police station regard cyber crime action take within prescribed time constraintbrbegnceae person directly use application help directly lodge complaint commissioner office get store commissioner database necessary action take strength belief team work team member leader hard ethical worker education detail january 2013 january 2016 b e yeshwantrao chavan nagpur maharashtra nagpur university diploma aggregate maharashtra state c education nagpur maharashtra maharashtra state test engineer skill detail android exprience 6 month cpp exprience 6 month database exprience 6 month excel exprience 6 month java exprience 6 month selenium exprience 12 month automation test exprience 12 month selenium webdriver exprience 12 month manual test exprience 6 month regression test exprience 6 monthscompany detail company maxgen technology description software test engineer work maxgen technology past 1 year',
#        'computer skill proficient m office word basic excel power point strength hard work loyalty creativity self motivate responsible initiative good people management skill positive attitudebntgbqlmkk knowledge windows internetckekjofvwqeducation detail bachelor electrical engineering electrical engineering nashik maharashtra guru gobind singh college engineering research centre diploma electrical engineering nashik maharashtra squnsobcudt mrynoolxhuv esajhwmuxoo siqmadshiyn polytechnic college test engineer skill detail excel exprience 6 month m office exprience 6 month word exprience 6 monthscompany detail company description department test responsibility check acb vcb circuit breakeriszogerzlf follow test conduct circuit breaker per drawingbrbegnceae 1 check breaker time 2 check contact resistance use contact resistance meter crm 3 check breaker insulation resistance ir 4 check breaker rack rack properly 5 check closing trip operation work properly check follow test conduct mcc pcc panel 1 insulation resistance ir test 2 contact resistance crm test 3 check connection mcc pcc panel per draw check follow test conduct transformer 1 insulation resistance ir test 2 transformer ratio test 3 transformer vector group test 4 magnetic balance test 5 magnetic current test 6 check transformer tap remotely well manually 7 check alarm trip protection command work properly per circuit diagram check test conduct hv cable 1 hi pot test 2 insulation resistance ir test check lv cable use megger ir test check relay connection per circuit diagram create defect list arise test try find solution minimize problem company trans power solution description lake site co op soc adi shankaracharya marg opp iit main gate powai 400076',
#        'willingness accept challengesbntgbqlmkk positive thinkingckekjofvwq good learnerqunsobcudt team playerrynoolxhuv declaration hereby declare mention information correct knowledge bear responsibility correctness mention particularssajhwmuxoo date name dongare mandakini murlidhar signature education detail june 2015 electronics telecommunication engineering kolhapur maharashtra shivaji university june 2012 education secondary higher secondary biqmadshiyneiszogerzlf electronics telecommunication jaywant college engineering management test engineer electronics engineer abacus electronics pvt ltd skill detail language c c exprience less 1 year month operate system windows 7 8 nt xp exprience less 1 year monthscompany detail company abacus electronics pvt ltd description duty perform electronic system test acceptance compliance warranty typesbrbegnceae develop test plan procedure electronic system maintain complete accurate documentation system test analyze troubleshoot test defect timely fashion write system assembly instruction resolve assembly issue accurately work supervisor plan coordinate test activity evaluate system performance suggest improvement understand interpret drawing schematic technical manual instruction also perform hardware test debug hardware pcbs follow company policy safely regulation work cross functional team complete assign job duty within deadline recommend process improvement enhance test efficiency company minilec india pvt ltd pirangoot description take responsibility quality company product work departmental manager production staff supplier ensure quality aim minimize cost rework waste maximize customer satisfaction product establish implement maintain quality management system measure control quality production process work aim eliminate cause quality issue reduce risk failure',
#        'computer skill software knowledge m power point m office c protius pcb design multisim micro wind matlab keil latex basic nternet fundamental software hardware knowledge project detail diploma project speed control dc motor use heart beatsbntgbqlmkk mini project water garden system use solar panelckekjofvwq final year project iris recognition systemqunsobcudteducation detail january 2016 education pune maharashtra pune university january 2010 ssc maharashtra board quality engineer quality engineer matrix technology skill detail matlab exprience 6 month pcb exprience 6 month pcb design exprience 6 monthscompany detail company matrix technology description company rb electronics description',
#        'good logical analytical skill positive attitude towards solve problem accept challenge team player leader good organizer presonal detail dob 20 07 1995bntgbqlmkk marital status singleckekjofvwqeducation detail july 2015 june 2018 electrical pune maharashtra sinhagad institute technology january 2012 diploma msbte kopargaon maharashtra kqunsobcudtbrynoolxhuvpsajhwmuxoopolytechnic january 2010 ssc siqmadshiyngiszogerzlfvidyalaya state board test engineer electrical engineer skill detail company detail company intelux electronics pvt ltd description 1brbegnceae power management system test department',
#        'personal skill quick learner eagerness learn new thing competitive attitude good leadership quality ability deal people diplomaticallybntgbqlmkk personal dossier father name dhanraj wagheducation detail january 2012 january 2016 bachelor engineering engineering pune maharashtra pune university january 2012 higher secondary certificate nashik maharashtra snd college engineering research center january 2010 secondary school certificate yeola maharashtra swami muktanand jrckekjofvwq college hsc maharashtra state board ssc maharashtra state bard rajapur uttar pradesh madhyamik vidya mandir rajapur test quality control engineer test quality control engineer rakesh transformer industry pvtqunsobcudt ltd skill detail company detail company rakesh transformer industry pvtrynoolxhuv ltd description responsibility conduct routine test type test temperature rise test special test transformer per iec 10 mva 33 kv class prepare test reportssajhwmuxoo routine test type test special test per 2026 1180 11171 iec 60076 test manual inspection plan power transformer distribution transformer inverter duty converter duty motor duty transformer furnace transformer auto transformer dry type vpi crt lt transformer special transformer test remote tap changer cubicle rtcc panel oltc operation ctr esun mriqmadshiyn functional test transformer accessory br prv mog wti oti set case failure test analysis root cause submit capa assist customer representative time inspectioniszogerzlf process test wind core assembly core coil assemblybrbegnceae handle 3rd party government body inspection preparation daily internal testing report send concern support certification audit iso bi calibration validation tool instrument measure equipment suggest client proper maintenance transformer documentation maintain record analyze test result maintain test ledger process quality inspection wind core assembly core coil assembly per standard per organizational norm pre dispatch quality inspection complete product implementation analysis company silverline electricals pvt ltd description routine test type test temperature rise test special test per 2026 1180 test manual inspection plan distribution transformer power transformer successfully handle responsibility erda test site commission transformer assist customer representative time inspection process test wind core assembly core coil assembly successfully handle 3rd party government body inspection preparation daily internal testing report send concern suggest client proper maintenance transformer',
#        'core skill project program management agile scrum management risk client management process improvement proposal rfe selenium rally ibm td platform python devops devsecops safe agile craft delivery test management project program finance profit maximization internal external audit software test quality assurance visual basic 6bntgbqlmkk0 m sql server oracle 8 8i conformiq hp qc qtp crystal report 8ckekjofvwq5 linguistic skill english hindi marathi tulu education detail january 2013 harvard january 2004 software engineering aptech january 2001 bachelor commerce commerce mumbai maharashtra mumbai university project manager project manager skill detail test exprience 63 month oracle exprience 6 month sql exprience 6 month audit exprience 6 month client management exprience 6 monthscompany detail company description thunderbird program one stop test shop cater enterprise wide business critical applicationsqunsobcudt part fix price engagement various type test like system regression sanity uat support get execute agile methodology application bill sale domainrynoolxhuv project various critical application list team size 80 memberssajhwmuxoo sale express ipad browser base mobile sale application use sale representative service solution provider sell enterprise product solution esign allow customer sign countersign digital version contract document ampd enterprise billing application offer new emerge billing product business community best business solution application performs consolidate bill report cru billing reporting foundation account bizcomp comp engine business support commission calculation enterprise business small business sale force via revenue unit base plan fast provide rate discount eligible school library cxmt let customer manage centrex line feature arrangement service without go standard service order procedureiqmadshiyn key responsibility manage lead aspect transition pre transition comprise multiple vendor transition drill session forward reverse shadow phase reverse presentation transition documentation signoff smp system appreciation document etc measure track test metric scorecard part vendor quality index vqi initiative measure track operate metric like onsite subcon index offshoring index leakage index utilization index tail index manage track submit project monthly financials invoice ensure 100 compliance client organization quality security process policy slas plan manage mitigate risk achieve automation target slas use conformiq selenium oscar tool participate proposal preparation expand revenue new business development manage track work allocation resourcing issue resolution test activity project ensure monthly delivery tl9k metric csl kms submit time pmr internal quality security group sqa quality gate external ernst young tl9k audit share weekly highlight report project health report regular dashboard reporting activity prepare csat action plan team prepare implement business continuity plan project timely conduct business continuity drill like call tree table top project rehearsal comparative analysis root cause analysis defect prevention exercise st e2e uat coordinate resource management quality learn security pmo business unit sub contractor rebadged ex staff management participate external technical interview hire drive new engagement company esaya software india pvt ltd description',
#        'education detail february 2006 february 2006 tybcom commerce mumbai business analyst business analyst skill detail company detail company motilal oswal description business analyst handle operation institutional equity maintain daily mi excel cag research derivative sale team prepare auto dashboard research sale trade team work excel macro create innovative report work block relate data work bd fund different geo work investor corporate meeting track corporate block fund interest sector company f description project description maintain prepare cash indent cash report cash position cash planning responsibility maintain daily mi excelbntgbqlmkk provide complete information mi atmckekjofvwq maintain prepare cash indent cash report cash positionqunsobcudt cash planning co ordinate bank cash departmentrynoolxhuv co ordinate custodian sajhwmuxoo degree course year pass grade institute university board percentage company angel broking description report assistant manager sriqmadshiyn manger responsibility handle team 14 quality assurance team member maintain daily mi excel team productivity maintain prepare repots add comment remark mail client modification give number mail report different branch coordinate rm provide complete information script client'],
#       dtype=object)

# %%
count_vectorizer = CountVectorizer()
tfidf_vectorizer = TfidfVectorizer()

# %%
count_vectorizer.fit(resumes)
tfidf_vectorizer.fit(resumes)
# Out:
# TfidfVectorizer()

# %% [markdown]
# ## Resume Search

# %%
def retrieval(resume: str, database: pandas.DataFrame, vectorizer, verbose=False, word2vec=False) -> str:
    if not word2vec:
        test_vector = vectorizer.transform([resume])
    else:
        import gensim.downloader
        word2vec_model = gensim.downloader.load('word2vec-google-news-300')

        def vectorize_documents(documents, word2vec_model):
            document_vectors = []
        
            for document in documents:
                tokens = document.lower().split()
                vectors = []
        
                for token in tokens:
                    if token in word2vec_model:
                        vectors.append(word2vec_model[token])
        
                if vectors:
                    document_vectors.append(sum(vectors) / len(vectors))
                else:
                    # Handle the case where all words are out-of-vocabulary
                    document_vectors.append([0] * 300)
            return document_vectors
        
        test_vector = vectorize_documents([resume], word2vec_model)[0]

    highest_similarity = 0
    most_similar = None
    for to_test in database.Resume.values:
        
        if not word2vec:
            similarity = cosine_similarity(test_vector, vectorizer.transform([to_test]))
        else:
            similarity = cosine_similarity([test_vector], 
                                           [vectorize_documents([to_test], word2vec_model)[0]])
            
        if verbose:
            print(f'Similarity between input query to document "{to_test[0:100]}..." = {similarity[0][0]}')
        if similarity[0][0] > highest_similarity:
            highest_similarity = similarity
            most_similar = to_test
    
    if verbose:
        print("***END***\n\n")
    return most_similar

# %% [markdown]
# ### Test within internal database

# %%
resumes[12] #Quick Test Example
# Out:
# 'education detail june 2012 may 2015 bbntgbqlmkka economics chennai tamil nadu sdnbvc hr skill detail company detail company anything solution description hr'

# %%
query = '''
june 2012 may 2015
'''

# %%
result = retrieval(query, resumes_df, tfidf_vectorizer, verbose=True)
print(result)
# Out:
# Similarity between input query to document "qwtnrvduof education detail may 2013 may 2017 bbntgbqlmkke uit rgpv data scientist data scientist ma..." = 0.057711712630515125
# Similarity between input query to document "qwtnrvduof area interest deep learn control system design program python electric machinery web deve..." = 0.021168073062769178
# Similarity between input query to document "skill r python sap hana tableau sap hana sql sap hana pal m sql sap lumira c linear program data mod..." = 0.0
# Similarity between input query to document "education detail mca ymcaust faridabad haryana data science internship skill detail data structure e..." = 0.0
# Similarity between input query to document "skill c basic iot python matlab data science machine learn html microsoft word microsoft excel micro..." = 0.16300143713293566
# Similarity between input query to document "skill python tableau data visualization r studio machine learn statistic iabac certify data scientis..." = 0.0
# Similarity between input query to document "education detail bbntgbqlmkktech rayat bahra institute engineering biotechnology data science data s..." = 0.005937851210589639
# Similarity between input query to document "personal skill ability quickly grasp technical aspect willingness learn high energy level result ori..." = 0.0
# Similarity between input query to document "expertise data quantitative analysis decision analytics predictive model data drive personalization ..." = 0.010057279716244772
# Similarity between input query to document "skill program language python panda numpy scipy scikit learn matplotlib sql java javascript jquerybn..." = 0.0
# Similarity between input query to document "education detail may 2013 may 2017 bbntgbqlmkke uit rgpv data scientist data scientist matelabs skil..." = 0.05795553664269348
# Similarity between input query to document "area interest deep learn control system design program python electric machinery web development ana..." = 0.021229676964209403
# Similarity between input query to document "qwtnrvduof ibntgbqlmkktckekjofvwq skill windows xp m office word excel look ups pivot table basic fu..." = 0.0
# Similarity between input query to document "qwtnrvduof education detail ba mumbai university hr skill detail hr operation exprience less 1 year ..." = 0.0
# Similarity between input query to document "education detail june 2012 may 2015 bbntgbqlmkka economics chennai tamil nadu sdnbvc hr skill detail..." = 0.3229427551841358
# Similarity between input query to document "education detail bba lovely professional university hr skill detail communication exprience 6 months..." = 0.0
# Similarity between input query to document "education detail mba acn college engineering mgt hr skill detail company detail company hr assistant..." = 0.0
# Similarity between input query to document "key skill computerize accounting tally sincere hard work management accounting income tax good commu..." = 0.17756325262316713
# Similarity between input query to document "train special education certificate course education detail july 2016 october 2018 mbntgbqlmkksc psy..." = 0.0
# Similarity between input query to document "computer knowledge proficient basic use m office microsoft dynamic ax software saiba softwareeducati..." = 0.0
# Similarity between input query to document "software skills general computer proficiency program langages know c c java web programming tool sof..." = 0.0
# Similarity between input query to document "technical skill typewrite tora spsseducation detail january 2017 mba chidambaram tamil nadu sn colle..." = 0.0
# Similarity between input query to document "ibntgbqlmkktckekjofvwq skill windows xp m office word excel look ups pivot table basic function powe..." = 0.0
# Similarity between input query to document "education detail ba mumbai university hr skill detail hr operation exprience less 1 year monthscompa..." = 0.0
# Similarity between input query to document "education detail bbntgbqlmkkcom llckekjofvwqbqunsobcudt university clacutta university burdwan advoc..." = 0.0
# Similarity between input query to document "education detail llbbntgbqlmkk dibrugarh university advocate skill detail legalckekjofvwq exprience ..." = 0.0
# Similarity between input query to document "education detail november 2016 january 2019 llm master law hyderabad telangana sultan ul uloom colle..." = 0.03179353718514514
# Similarity between input query to document "skill know english native speaker ielts overall 8 listen 8 read 8 write 7 speak 8bntgbqlmkk5 hindi b..." = 0.056853137754131075
# Similarity between input query to document "qualification introduction computer extraeducation detail january 2001 january 2003 master law chenn..." = 0.0
# Similarity between input query to document "skill natural language proficient english hindi marathibntgbqlmkk computer skills proficient m offic..." = 0.08039093213774595
# Similarity between input query to document "skill legal write efficient researcher legal education family law criminal defence environment law l..." = 0.040651145370988316
# Similarity between input query to document "good grasping quality skillful work education detail march 2013 march 2018 bbntgbqlmkk ackekjofvwq l..." = 0.0
# Similarity between input query to document "hard work quick learnereducation detail june 2014 may 2017 llb law mumbai maharashtra mumbai univers..." = 0.12947223073922506
# Similarity between input query to document "technical qualification windows msbntgbqlmkk officeeducation detail llckekjofvwqb guwahati assam uni..." = 0.017493952238788
# Similarity between input query to document "good communication skill quick learner keen find solutionseducation detail mba masibqtserxdybsvdazdw..." = 0.0
# Similarity between input query to document "operate system windows xp vista 07education detail january 2018 mbntgbqlmkkfckekjofvwqa paint nagpur..." = 0.026166700335856538
# Similarity between input query to document "additional qualification april 2000 web design course average computer skillseducation detail januar..." = 0.0
# Similarity between input query to document "education detail january 2017 rachana sansad school interior deign january 2013 holy family high sch..." = 0.0
# Similarity between input query to document "skill course skill name board year pass grade intermediate grade draw art examination committee 2011..." = 0.07416007590975712
# Similarity between input query to document "good communication skill quick learner keen find solutionseducation detail mba market international ..." = 0.0
# Similarity between input query to document "education detail august 2018 january 2021 entermediate math mumbai maharashtra sunbeam academy samne..." = 0.0
# Similarity between input query to document "technical skill web technology angular j html5 css3 sas bootstrap jquery javascript softkehdwhplubuf..." = 0.0
# Similarity between input query to document "technical skill web technology angular j html5 css3 sas bootstrap jquery javascriptbntgbqlmkk softwa..." = 0.012209603617977106
# Similarity between input query to document "education detail january 2016 bbntgbqlmkkscckekjofvwq information technology mumbai maharashtra univ..." = 0.030983642222260774
# Similarity between input query to document "skill languages c basic java basic web technology html5 css3 bootstrap javascript jquery corel draw ..." = 0.052755678605218195
# Similarity between input query to document "education detail bbntgbqlmkkcckekjofvwqa bachelor computer application pune maharashtra pune univers..." = 0.0
# Similarity between input query to document "skill knowledge software computer auto cad include diploma academic syllabus mscit cnc program fanuc..." = 0.0
# Similarity between input query to document "education detail january 2018 bachelor engineering engineering mumbai maharashtra mgm college engine..." = 0.0
# Similarity between input query to document "education detail june 2014 june 2018 mechanical engineering pune maharashtra savitribai phule pune u..." = 0.03596245174929085
# Similarity between input query to document "hard work personbntgbqlmkk self confident mould work environmentsckekjofvwqeducation detail january ..." = 0.0
# Similarity between input query to document "education detail may 1999 september 2002 diploma mechanical engg mumbai maharashtra institute mechan..." = 0.05095756321107757
# Similarity between input query to document "education detail bachelor bachelor commerce india guru nanak high school sale managerarnbsmpjmniuobv..." = 0.0
# Similarity between input query to document "key skill plan strategizing presentation skill client relationship energy level enquiry generation a..." = 0.021427626423623166
# Similarity between input query to document "skill ms officebntgbqlmkk photoshopckekjofvwq sql serverqunsobcudteducation detail june 2015 bachelo..." = 0.040683297498698964
# Similarity between input query to document "skill set multi task collaborative optimistic thinking effective teamleader team trainer visualize w..." = 0.03500120933439746
# Similarity between input query to document "education detail bachelor bachelor commerce india guru nanak high school sale manager skill detail d..." = 0.0
# Similarity between input query to document "skill 1bntgbqlmkk m office 2ckekjofvwq good communication skill convince power 3qunsobcudt knowledge..." = 0.0
# Similarity between input query to document "education detail january 1992 january 2003 first year science mumbai maharashtra st micheal hguslvzs..." = 0.0
# Similarity between input query to document "personal skill good verbal write communication skill ability deal people diplomatically willingness ..." = 0.0
# Similarity between input query to document "skill computer easily operate operating system like window 10bntgbqlmkk work m office word excel pow..." = 0.011576703347474487
# Similarity between input query to document "education detail january 2009 pbntgbqlmkkgckekjofvwq sport science drqunsobcudt bmn college home sci..." = 0.0
# Similarity between input query to document "education detail may 2014 diploma nutrition education bengaluru karnataka ignou university june 2004..." = 0.030723855045880002
# Similarity between input query to document "education detail january 1992 january 2003 first year science mumbai maharashtra st micheal high per..." = 0.0
# Similarity between input query to document "education detail january 2018 mbntgbqlmkksckekjofvwq nutrition exercise physiology new york ny teach..." = 0.0
# Similarity between input query to document "education detail b e civil engineering civil engineering chennai tamil nadu anna university zojyteva..." = 0.0
# Similarity between input query to document "education detail january 2005 sbntgbqlmkksckekjofvwqc baramati maharashtra mqunsobcudterynoolxhuvssa..." = 0.0
# Similarity between input query to document "skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qunsobcudtcatia 4rynoolxhuvword excel 5sajhwmuxoophotosho..." = 0.01507844068775558
# Similarity between input query to document "computer knowledge drafting tool autocadbntgbqlmkk package ms office application operate system wind..." = 0.05340937461828439
# Similarity between input query to document "personal skill passionate towards learn new skillsbntgbqlmkk hardworking sense responsibilityckekjof..." = 0.0
# Similarity between input query to document "education detail bbntgbqlmkke civil engineering civil engineering chennai tamil nadu anna university..." = 0.0
# Similarity between input query to document "computer skill holder valid ksa license basic computer m office autocad 2006education detail january..." = 0.011413484346451046
# Similarity between input query to document "education detail august 2010 may 2017 electronics communication jabalpur madhya pradesh asuhmczcwiom..." = 0.122534697928492
# Similarity between input query to document "technical skill skill java sql pl sql c c bootstrap jsp ext j operate system windows tool toad eclip..." = 0.0
# Similarity between input query to document "technical strength computer language java j2ee swift html shell script mysql databases mysql tool sv..." = 0.053538433710718925
# Similarity between input query to document "education detail january 2013 master engineering information technology pune maharashtra mbntgbqlmkk..." = 0.020756753535755113
# Similarity between input query to document "education detail pjlce java developer java developer skill detail c exprience le 1 year month c expr..." = 0.0
# Similarity between input query to document "technicalskills springmvc hibernate jdbc java j2ee azureweb suntechnologies service jsp strut servle..." = 0.027254914880217113
# Similarity between input query to document "operate system windows xp 7 10bntgbqlmkk tool package visual basic 6ckekjofvwq0 uml packet tracer we..." = 0.05885144650751024
# Similarity between input query to document "computer skill languages script jsp servlet html cs java script jquery ajax spring hibernate operati..." = 0.0
# Similarity between input query to document "education detail january 2016 bbntgbqlmkke information technology pune maharashtra sawitribai phule ..." = 0.0
# Similarity between input query to document "technical skill program language java servlet jsp spring boot bntgbqlmkk web technology html5 css3 b..." = 0.019845582787582427
# Similarity between input query to document "skill 1 team lead 2 self motivate 3 hard work strength ready learn new programming languages punctua..." = 0.0
# Similarity between input query to document "skill language java operate system windows linux centos 6bntgbqlmkk6 database oracle sql derby embed..." = 0.0
# Similarity between input query to document "education detail august 2010 may 2017 electronics communication jabalpur madhya pradesh takshshila i..." = 0.07272053304074082
# Similarity between input query to document "technical skill train project acquire skill language know c c j2ee spring hibernatebntgbqlmkk test f..." = 0.017904251205261807
# Similarity between input query to document "education detail computer science mumbai maharashtra mumbai university hsc mumbai maharaintakupehtrj..." = 0.0
# Similarity between input query to document "technical skill application server iis 6bntgbqlmkk0 jboss 7ckekjofvwq1qunsobcudt database sql oracle..." = 0.0
# Similarity between input query to document "skill area exposure model tool bizagi m visio prototyping tool indigo studiobntgbqlmkk documentation..." = 0.0
# Similarity between input query to document "technological skill knowledge computer window platformbntgbqlmkk fluency m office application excel ..." = 0.0
# Similarity between input query to document "education detail february 2006 february 2006 tybcom commerce mumbai business analyst business analys..." = 0.0
# Similarity between input query to document "key skill requirement gather requirement analysis design specification client communication system d..." = 0.008418583546734927
# Similarity between input query to document "education detail computer science mumbai maharashtra mumbai university hsc mumbai maharashtra mahara..." = 0.0
# Similarity between input query to document "skill etl data warehouse sql pl sql basic core java basic python tool inffrkxstdskstyekrrrxsfjmixyzk..." = 0.0
# Similarity between input query to document "competency sap business intelligence version sap bo 4bntgbqlmkk2 bo tool design studio idt webi udt ..." = 0.0
# Similarity between input query to document "education detail july 2008 february 2012 computer science nagpur maharashtra nagpur university sap h..." = 0.009155675619230018
# Similarity between input query to document "education detail january 2016 bachelor engineering lean project mumbai maharashtra mumbai university..." = 0.0
# Similarity between input query to document "education detail sap technical architect sap technical consultant ale idoc odata fiori s4hana ewm ap..." = 0.0
# Similarity between input query to document "skill etl data warehouse sql pl sql basic core java basic python tool sap bod sap bo oracle 11g syba..." = 0.022681830396557554
# Similarity between input query to document "education detail may 2013 master computer application mumbai maharashtra imcost college april 2010 b..." = 0.07840810360736705
# Similarity between input query to document "social skill ability establish trust work teambntgbqlmkk determine good work ethicsckekjofvwq abilit..." = 0.010575122377534963
# Similarity between input query to document "technical skill automation test selenium webdriver testngbntgbqlmkk test framework testng data drive..." = 0.0
# Similarity between input query to document "skill agile methodology scrum kanban extreme program xp test driven development tdd feature drive de..." = 0.0
# Similarity between input query to document "technical skill summary complete corporate training manual automation test source code technology pu..." = 0.01519818648508095
# Similarity between input query to document "education detail bbntgbqlmkktech electronics instrumentation engineering jaunpur uttar pradesh vbs p..." = 0.009016396090397037
# Similarity between input query to document "technical skill languages core java automation test tool selenium web driver idebntgbqlmkk dbms m sq..." = 0.03445629035354288
# Similarity between input query to document "excellent grasp power learn new concept technologybntgbqlmkk highly motivate team player strong work..." = 0.0
# Similarity between input query to document "skill 1 mc office 2 autocad 2016 3 introductory knowledge eplan 4 sap erp product specifuwawekogehgj..." = 0.0
# Similarity between input query to document "achievement orient people management skill ability manage change easebntgbqlmkk proven strength prob..." = 0.0
# Similarity between input query to document "education detail july 2016 may 2019 electrical electronics engineering bhopal madhya pradesh rgpv ju..." = 0.12488576774569514
# Similarity between input query to document "education detail january 2012 january 2013 bbntgbqlmkkeckekjofvwq electrical shivaji university sept..." = 0.0143358401874022
# Similarity between input query to document "skill 1 mc office 2 autocad 2016 3 introductory knowledge eplan 4 sap erp product specific cod stren..." = 0.03584937013640651
# Similarity between input query to document "education detail electrical engineering skill detail microsft office excell power point exprience 12..." = 0.0
# Similarity between input query to document "key competency multi operation management people management customer service email mi vendor client ..." = 0.007625747850197111
# Similarity between input query to document "skill well verse m office internet application various erp system implement company iebntgbqlmkksage..." = 0.01053437956452913
# Similarity between input query to document "education detail august 2000 bbntgbqlmkke electronics pune maharashtra pune university operation man..." = 0.011555651706143885
# Similarity between input query to document "education detail bca vinayaka mission university operation manager operation manager skill detail op..." = 0.0
# Similarity between input query to document "technical skill responsibility hand experience production maintenance projootyuqatzbsoseaaglmprtnjpc..." = 0.0
# Similarity between input query to document "education detail june 2013 june 2016 diploma computer science pune maharashtra aissms june 2016 purs..." = 0.17094889763568885
# Similarity between input query to document "technical proficiency platform ubuntu fedora cent o windows database mysql languages python tensorfl..." = 0.0
# Similarity between input query to document "technical skill languages python python framework django drf databases mysql oracle sqlite mongodb w..." = 0.015275015744385308
# Similarity between input query to document "operate system windows others m excel m office m power point key project handle project title fruit ..." = 0.0
# Similarity between input query to document "technical skill responsibility hand experience production maintenance projectsbntgbqlmkk experience ..." = 0.0
# Similarity between input query to document "training attend 1bntgbqlmkk successfully complete esd program conduct zensar technology pune 2017cke..." = 0.0698827919331925
# Similarity between input query to document "skill visa b1 visa usa onsite visit sweden u seattle education detail january 2013 polmibsbidboelyja..." = 0.0
# Similarity between input query to document "software proficiency languages basic c sql pl sql java javaee javascript html cs jquery mysql spring..." = 0.022830170355884402
# Similarity between input query to document "core competency ant maven git bitbucket jenkins linux ansible shell script requirement gather contin..." = 0.030248538010987047
# Similarity between input query to document "technical skill key skill ms technology bntgbqlmkknet sharepoint m sql oracle pl sql project managem..." = 0.031223123077037764
# Similarity between input query to document "total experience 15 yearsbntgbqlmkk core expertise data base design php python mysql javascript html..." = 0.0
# Similarity between input query to document "technical skill hp alm rtc jira as400 iseries sql test automation x framework hour hsbc framework uf..." = 0.0
# Similarity between input query to document "skill visa b1 visa usa onsite visit sweden u seattle education detail january 2013 post graduate dip..." = 0.0
# Similarity between input query to document "skill set experience implement troubleshoot network security solution planninsytwcwuhotunyribgnoqnqp..." = 0.0
# Similarity between input query to document "skill set cisco certify network associate ccna basic knowledge network ethernet medium ethernet comm..." = 0.0
# Similarity between input query to document "communication skill write skill english good certainly clear speakerbntgbqlmkk comfortable speak fro..." = 0.06898096651411817
# Similarity between input query to document "technical expertise cisco asa checkpoint firewall gaia splat palo alto firewalls firewall management..." = 0.0
# Similarity between input query to document "skill set experience implement troubleshoot network security solution plan implementation knowledge ..." = 0.014618096316361918
# Similarity between input query to document "operate system windows linux ubuntu network technology cisco rout switch intervlan rout dynamic prot..." = 0.023417734756022185
# Similarity between input query to document "core competency maintain process ensure project management documentation report plazgslwgchqcbitfaok..." = 0.0
# Similarity between input query to document "area expertise profile around 10 plus year proven experience best global brand wipro expertise pmo i..." = 0.0
# Similarity between input query to document "skill exceptional communication network skill successful work team environment well independently ab..." = 0.0
# Similarity between input query to document "core competency maintain process ensure project management documentation report plan relevant accura..." = 0.0
# Similarity between input query to document "technical expertise operate system microsoft window server 2003 2008 2008 r2 2012 database technolog..." = 0.010823839947756824
# Similarity between input query to document "technical skill operate system m window server 2012 2008 xp software tool ms litespeed idera sql saf..." = 0.06600208791468903
# Similarity between input query to document "skillset oracle dba mysql mariadb postgresql database administration itskills sql oracle 10g 11g mys..." = 0.0
# Similarity between input query to document "education detail january 2016 bscbntgbqlmkk mumbai maharashtra mumbai university january 2013 hckekj..." = 0.0
# Similarity between input query to document "technical skill operate system linux windows server 2012 r2 windows 98 window 2000 xp tool utility p..." = 0.023715287490114898
# Similarity between input query to document "technical skill databases oracle rdbms 10g 11g 12c technology utility data pump rman data guard asm ..." = 0.0
# Similarity between input query to document "software skill rdbms m sql server 2000 2005 2008 2012 2014 operate system windows xp 7 window server..." = 0.026386922899981013
# Similarity between input query to document "area expertise oracle databases 12c 11g 10g weblogic 12c 11g grid infrastructure rman asm middleware..." = 0.0
# Similarity between input query to document "education detail may 2011 may 2014 bachelor science information technology mumbai maharashtra mumbai..." = 0.02255120921495603
# Similarity between input query to document "technical skill sql oracle v10 v11 v12 r program python linear regression machine learn statistical ..." = 0.04138572678584104
# Similarity between input query to document "technical expertise db languages sql database tool sql server 2014 2017 postgresql 9bntgbqlmkk5 9cke..." = 0.019381382891904334
# Similarity between input query to document "education detail hadoop developer hadoop developer infosys skill detail company detaipbmhddyaktgxfyu..." = 0.0
# Similarity between input query to document "operate system linux ubuntu window 2007 08 tool tableau svn beyond comparebntgbqlmkkeducation detail..." = 0.0
# Similarity between input query to document "area expertise big data ecosystem hadoop hdfs mapreduce hive pig sqoop hbase oozie spark pyspark hue..." = 0.011858004909180219
# Similarity between input query to document "technical skill set programming language apache hadoop python shell script sql technology hive pig s..." = 0.02106837445616099
# Similarity between input query to document "technical skill program language c c java bntgbqlmkknetckekjofvwq j2ee html5 cs mapreduce script lan..." = 0.039172630227639706
# Similarity between input query to document "technical skill set big data ecosystem hadoop hdfs hbase map reduce sqoop hive pig spark core flumeb..." = 0.0
# Similarity between input query to document "education detail hadoop developer hadoop developer infosys skill detail company detail company infos..." = 0.0
# Similarity between input query to document "skill set hadoop map reduce hdfs hive sqoop javabntgbqlmkk duration 2016 2017ckekjofvwq role hadoop ..." = 0.0
# Similarity between input query to document "technical summary knowledge informatica power center ver 9 1 10 etl tool mapping desinnpdiyggrhbhqcf..." = 0.0
# Similarity between input query to document "technicalproficiencies db oracle 11g domain investment banking advertising insurancebntgbqlmkk progr..." = 0.017593408286365672
# Similarity between input query to document "education detail january 2015 bachelor engineering extc mumbai maharashtra mumbai university january..." = 0.037013306056224354
# Similarity between input query to document "skill set talend big data informatica power center microsoft sql server sql platform 6bntgbqlmkk2cke..." = 0.0165288132459136
# Similarity between input query to document "technical summary knowledge informatica power center verbntgbqlmkk 9ckekjofvwq1 10 etl tool map desi..." = 0.0
# Similarity between input query to document "computer skill yesbntgbqlmkk sql knowledge yes unix knowledge yes data warehouse knowledge yes ab in..." = 0.08097836561805652
# Similarity between input query to document "technical skill web technology asp net html cs jquery languages c c c net mnyqrqxwvaosysvwoynhdsznhe..." = 0.0
# Similarity between input query to document "participate intra college cricket competition various sport eventsbntgbqlmkk group dance college cul..." = 0.041448665712120004
# Similarity between input query to document "education detail january 2014 education detail pune maharashtra university pune january 2010 bbntgbq..." = 0.0
# Similarity between input query to document "technology aspbntgbqlmkknet mvc 3ckekjofvwq0 4qunsobcudt0 5rynoolxhuv0 unit test entity framework 6s..." = 0.04258542094224335
# Similarity between input query to document "technical skill category skill language c c oop dot net technology aspbntgbqlmkknet mvc adockekjofvw..." = 0.03823801337067037
# Similarity between input query to document "technical skill program language c bntgbqlmkknet web technology aspckekjofvwqnet mvc web api angular..." = 0.01731474873641999
# Similarity between input query to document "technical skill web technology asp bntgbqlmkknet html cs jqueryckekjofvwq languages c c c qunsobcudt..." = 0.0
# Similarity between input query to document "technical skill languages c asp bntgbqlmkknet mvc html cs javascript angularjs primary skill entity ..." = 0.0
# Similarity between input query to document "skill strong c fundamental problem solve ethereum smart contract solidity skill golang node angular ..." = 0.0
# Similarity between input query to document "key skill program language c c python apex visualforce database mysql framework django technology sa..." = 0.0
# Similarity between input query to document "software skill languages c c java operate system windows xp 7 ubuntu rdbms oracle sql database sql p..." = 0.010732353358503251
# Similarity between input query to document "skill bitcoin ethereum solidity hyperledger beginner go beginner r3 corda beginner tendermint nodejs..." = 0.0
# Similarity between input query to document "hobby play chess solve rubik cube watch series language english hindi marathi education detail janua..." = 0.0
# Similarity between input query to document "good logical analytical skill positive attitude towards solve problem accept uexngsbjynlemolnrjaqtca..." = 0.0
# Similarity between input query to document "computer proficiency basic m office powerpoint word outlook excel language know basic c cpp javabntg..." = 0.0
# Similarity between input query to document "computer skill proficient m office word basic excel power point strength hard work loyalty creativit..." = 0.0
# Similarity between input query to document "willingness accept challengesbntgbqlmkk positive thinkingckekjofvwq good learnerqunsobcudt team play..." = 0.08546477028976639
# Similarity between input query to document "computer skill software knowledge m power point m office c protius pcb design multisim micro wind ma..." = 0.0
# Similarity between input query to document "skill set o window xp 7 8 8bntgbqlmkk1 10 database mysql sql server 2005 2008 2012 language core jav..." = 0.017760762041429547
# Similarity between input query to document "good logical analytical skill positive attitude towards solve problem accept challenge team player l..." = 0.13315488904892717
# Similarity between input query to document "personal skill quick learner eagerness learn new thing competitive attitude good leadership quality ..." = 0.020705970506133892
# Similarity between input query to document "core skill project program management agile scrum management risk client management process improvem..." = 0.0
# Similarity between input query to document "education detail february 2006 february 2006 tybcom commerce mumbai business analyst business analys..." = 0.0
# ***END***
#
#
# education detail june 2012 may 2015 bbntgbqlmkka economics chennai tamil nadu sdnbvc hr skill detail company detail company anything solution description hr

# %%
# %timeit retrieval(query, resumes_df, count_vectorizer)
# Out:
# 78.4 ms ± 351 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit retrieval(query, resumes_df, tfidf_vectorizer)
# Out:
# 107 ms ± 554 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit retrieval(query, resumes_df, tfidf_vectorizer, word2vec=True)
# Out:
# 21.2 s ± 49.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Test within external database

# %%
test_resumes = test_df.Resume
test_resumes
# Out:
# 0     skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 1     skill set talend big data informatica power ce...
# 2     train special education certificate course edu...
# 3     education detail bba lovely professional unive...
# 4     computer knowledge drafting tool autocadbntgbq...
# 5     education detail july 2016 may 2019 electrical...
# 6     education detail bbntgbqlmkkcckekjofvwqa bache...
# 7     technicalskills springmvc hibernate jdbc java ...
# 8     education detail mba acn college engineering m...
# 9     software skill rdbms m sql server 2000 2005 20...
# 10    education detail january 2009 pbntgbqlmkkgckek...
# 11    skill visa b1 visa usa onsite visit sweden u s...
# 12    technical skill web technology angular j html5...
# 13    technical skill program language c c java bntg...
# 14    education detail bachelor bachelor commerce in...
# 15    skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qun...
# 16    education detail bca vinayaka mission universi...
# 17    skill set hadoop map reduce hdfs hive sqoop ja...
# 18    skill legal write efficient researcher legal e...
# 19    technical skill languages python python framew...
# 20    education detail bbntgbqlmkke civil engineerin...
# 21    skill strong c fundamental problem solve ether...
# 22    core competency maintain process ensure projec...
# 23    computer knowledge proficient basic use m offi...
# 24    education detail bachelor bachelor commerce in...
# 25    good logical analytical skill positive attitud...
# 26    skill python tableau data visualization r stud...
# 27    technical skill web technology asp bntgbqlmkkn...
# 28    education detail bbntgbqlmkkcom llckekjofvwqbq...
# 29    education detail sap technical architect sap t...
# 30    participate intra college cricket competition ...
# 31    skill program language python panda numpy scip...
# Name: Resume, dtype: object

# %%
test_labels = test_df.Category
test_labels
# Out:
# 0                    Testing
# 1              ETL Developer
# 2                         HR
# 3                         HR
# 4             Civil Engineer
# 5     Electrical Engineering
# 6              Web Designing
# 7             Java Developer
# 8                         HR
# 9                   Database
# 10        Health and fitness
# 11           DevOps Engineer
# 12             Web Designing
# 13                    Hadoop
# 14                     Sales
# 15            Civil Engineer
# 16        Operations Manager
# 17                    Hadoop
# 18                  Advocate
# 19          Python Developer
# 20            Civil Engineer
# 21                Blockchain
# 22                       PMO
# 23                        HR
# 24                     Sales
# 25                   Testing
# 26              Data Science
# 27          DotNet Developer
# 28                  Advocate
# 29             SAP Developer
# 30          DotNet Developer
# 31              Data Science
# Name: Category, dtype: object

# %%
def string_subset(string_value: str):
    max_len = len(string_value)
    
    subset_length = random.randint(1, max_len // 3)
    
    start = random.randint(1, max_len - subset_length)
    end = start + subset_length
    
    return string_value[start:end]

# %%
test_queries = numpy.array([string_subset(query) for query in test_resumes])
test_queries = pandas.DataFrame(test_queries, columns=['Resume'])
test_queries
# Out:
#                                                Resume
# 0    month database test exprience 6 monthscompany...
# 1   stqunsobcudt francis talend etl developer tale...
# 2   lappuram kerala calicut university july 2013 m...
# 3                                           exprience
# 4   d muweilah commercial near alfalah round sharj...
# 5                         ail july 2016 may 2019 elec
# 6   erapy project iii vitsanindia system technolog...
# 7   uter engineering nashik maharashtra late giszo...
# 8                        mgt hr skill detail company
# 9    name barclays technology centre indiackekjofv...
# 10  cle design customize diet plan confident commu...
# 11                                           bhtaeiyg
# 12  pplication achieve target give time frame make...
# 13  bm db2 tool ibm rational rise r weka operate s...
# 14  nanak high school sale manager skill detail da...
# 15  neer company girija construction devolopers de...
# 16  nitiate goal set exercise operation team lob p...
# 17       t algorithm optimization backend productryno
# 18  bank private bank client federal bank chinchwa...
# 19  network inventory network communication fault ...
# 20  793 cu 42 hour world dh600 million 163 million...
# 21  hain protocolrynoolxhuv roll multiple blockcha...
# 22                      t documentation report plazgs
# 23  r garment spin mill feb 2018 still sri ramesh ...
# 24                       rce india guru nanak high sc
# 25              ngsbjynlemolnrjaqtcafevsmiyqenfxfuemh
# 26                    cessing data use python excel r
# 27  gy description work web application use asp c ...
# 28                         preparation plaint account
# 29  y description 13 year work experience sap incl...
# 30  ion various sport eventsbntgbqlmkk group dance...
# 31  celerate review process run analytics generate...

# %%
num = 2
test_resumes[2]
# Out:
# 'train special education certificate course education detail july 2016 october 2018 mbntgbqlmkksc psychology specialization organizational behaviour malappuram kerala calicut university july 2013 march 2016 bsc psychology thrissur prajyoti niketan college hr skill detail company detail company description do 30 day internship hr department foster hot bread kinfra malappuram kerala also do 60 day internship santhwana institute counsel psychotherapy cochin kerala counsellor'

# %%
queryTest = '''
department foster hot bread kinfra mal
'''

# %%
result = retrieval(queryTest, test_df, tfidf_vectorizer)
print(result)
# Out:
# train special education certificate course education detail july 2016 october 2018 mbntgbqlmkksc psychology specialization organizational behaviour malappuram kerala calicut university july 2013 march 2016 bsc psychology thrissur prajyoti niketan college hr skill detail company detail company description do 30 day internship hr department foster hot bread kinfra malappuram kerala also do 60 day internship santhwana institute counsel psychotherapy cochin kerala counsellor

# %% [markdown]
# #### Evaluation

# %% [markdown]
# Count Vectorizer

# %%
y_pred = test_queries['Resume'].apply(lambda x: retrieval(x, test_df, count_vectorizer))
y_pred = y_pred.fillna('wrong')
y_pred
# Out:
# 0     skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 1     skill set talend big data informatica power ce...
# 2     train special education certificate course edu...
# 3     technical skill web technology asp bntgbqlmkkn...
# 4     computer knowledge drafting tool autocadbntgbq...
# 5     education detail july 2016 may 2019 electrical...
# 6     education detail bbntgbqlmkkcckekjofvwqa bache...
# 7     technicalskills springmvc hibernate jdbc java ...
# 8     education detail mba acn college engineering m...
# 9     software skill rdbms m sql server 2000 2005 20...
# 10    education detail january 2009 pbntgbqlmkkgckek...
# 11                                                wrong
# 12    technical skill web technology angular j html5...
# 13    technical skill program language c c java bntg...
# 14    education detail bachelor bachelor commerce in...
# 15    skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qun...
# 16    education detail bca vinayaka mission universi...
# 17    skill set hadoop map reduce hdfs hive sqoop ja...
# 18    skill legal write efficient researcher legal e...
# 19    technical skill languages python python framew...
# 20    education detail bbntgbqlmkke civil engineerin...
# 21    skill strong c fundamental problem solve ether...
# 22    core competency maintain process ensure projec...
# 23    computer knowledge proficient basic use m offi...
# 24    education detail bachelor bachelor commerce in...
# 25                                                wrong
# 26    skill python tableau data visualization r stud...
# 27    technical skill web technology asp bntgbqlmkkn...
# 28    education detail bbntgbqlmkkcom llckekjofvwqbq...
# 29    education detail sap technical architect sap t...
# 30    participate intra college cricket competition ...
# 31    skill program language python panda numpy scip...
# Name: Resume, dtype: object

# %%
accuracy_score(test_resumes, y_pred)
# Out:
# 0.90625

# %% [markdown]
# Tf-Idf Vectorizer

# %%
y_pred = test_queries['Resume'].apply(lambda x: retrieval(x, test_df, tfidf_vectorizer))
y_pred = y_pred.fillna('wrong')
y_pred
# Out:
# 0     skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 1     skill set talend big data informatica power ce...
# 2     train special education certificate course edu...
# 3     technical skill web technology asp bntgbqlmkkn...
# 4     computer knowledge drafting tool autocadbntgbq...
# 5     education detail july 2016 may 2019 electrical...
# 6     education detail bbntgbqlmkkcckekjofvwqa bache...
# 7     technicalskills springmvc hibernate jdbc java ...
# 8     education detail mba acn college engineering m...
# 9     software skill rdbms m sql server 2000 2005 20...
# 10    education detail january 2009 pbntgbqlmkkgckek...
# 11                                                wrong
# 12    technical skill web technology angular j html5...
# 13    technical skill program language c c java bntg...
# 14    education detail bachelor bachelor commerce in...
# 15    skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qun...
# 16    education detail bca vinayaka mission universi...
# 17    skill set hadoop map reduce hdfs hive sqoop ja...
# 18    skill legal write efficient researcher legal e...
# 19    technical skill languages python python framew...
# 20    education detail bbntgbqlmkke civil engineerin...
# 21    skill strong c fundamental problem solve ether...
# 22    core competency maintain process ensure projec...
# 23    computer knowledge proficient basic use m offi...
# 24    education detail bachelor bachelor commerce in...
# 25                                                wrong
# 26    skill python tableau data visualization r stud...
# 27    technical skill web technology asp bntgbqlmkkn...
# 28    education detail bbntgbqlmkkcom llckekjofvwqbq...
# 29    education detail sap technical architect sap t...
# 30    participate intra college cricket competition ...
# 31    skill program language python panda numpy scip...
# Name: Resume, dtype: object

# %%
accuracy_score(test_resumes, y_pred)
# Out:
# 0.90625

# %% [markdown]
# Word2Vec Vectorizer

# %%
y_pred = test_queries['Resume'].apply(lambda x: retrieval(x, test_df, count_vectorizer, word2vec=True))
y_pred = y_pred.fillna('wrong')
y_pred
# Out:
# 0     skill python tableau data visualization r stud...
# 1     education detail bbntgbqlmkkcckekjofvwqa bache...
# 2     train special education certificate course edu...
# 3     education detail sap technical architect sap t...
# 4     computer knowledge drafting tool autocadbntgbq...
# 5     technicalskills springmvc hibernate jdbc java ...
# 6     education detail bbntgbqlmkkcckekjofvwqa bache...
# 7     technicalskills springmvc hibernate jdbc java ...
# 8     education detail mba acn college engineering m...
# 9     skill strong c fundamental problem solve ether...
# 10    education detail january 2009 pbntgbqlmkkgckek...
# 11                                                wrong
# 12    education detail bca vinayaka mission universi...
# 13    technical skill program language c c java bntg...
# 14    education detail bachelor bachelor commerce in...
# 15    skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qun...
# 16    education detail bca vinayaka mission universi...
# 17    education detail bbntgbqlmkkcckekjofvwqa bache...
# 18    skill legal write efficient researcher legal e...
# 19    technical skill languages python python framew...
# 20    education detail bbntgbqlmkke civil engineerin...
# 21    skill strong c fundamental problem solve ether...
# 22    education detail bbntgbqlmkke civil engineerin...
# 23    computer knowledge proficient basic use m offi...
# 24    participate intra college cricket competition ...
# 25                                                wrong
# 26    skill python tableau data visualization r stud...
# 27    technical skill web technology asp bntgbqlmkkn...
# 28    education detail bbntgbqlmkkcom llckekjofvwqbq...
# 29    education detail sap technical architect sap t...
# 30    participate intra college cricket competition ...
# 31    skill program language python panda numpy scip...
# Name: Resume, dtype: object

# %%
accuracy_score(test_resumes, y_pred)
# Out:
# 0.65625

# %% [markdown]
# #### Test on own resume

# %%
with open('personalResume.txt', 'r', encoding='utf-8') as f:
    own_resume = f.read()
    
own_resume
# Out:
# "Name: Chong Jia Shuo\nEmail: 222978d@mymail.nyp.edu.sg\nHandphone: 9777 1234\nLinkedIn: https://www.linkedin.com/in/js-chong-30766b273\nNationality: Singaporean\nLanguages Known: English and Chinese\nAbout Me\nAs an individual who has developed a strong appreciation and passion for Artificial Intelligence (AI) during my study at NYP, I have actively engaged in independent, self-directed learning. I have taught myself various programming languages and fundamental theories of AI (Probability & Calculus, etc.). Currently, I am looking to add value to an organisation by using my knowledge and expertise to develop various AI models and algorithms, as well as share these outcomes with multiple stakeholders.\nEducation\n•\t‘O’ Level Graduate, Chung Cheng High School (Yishun)\no\tELR2B2 Nett 7\n•\tDiploma in AI and Data Engineering, Nanyang Polytechnic, Singapore, Year 2\no\tGPA 4.0\no\tRelevant Distinctions in:\n\uf0a7\tProgramming\n\uf0a7\tData Preparation & Visualization\n\uf0a7\tData Management\n\uf0a7\tMachine Learning\n\uf0a7\tCloud Computing & Platform\n\uf0a7\tData Engineering Project\n\uf0a7\tAnalytical Geometry (Diploma Plus Module)\n\uf0a7\tApplied Calculus (Diploma Plus Module)\nRelevant Skills\nProficient Skills:\n•\tPython\no\tScientific Libraries, i.e., NumPy and Pandas\n•\tMicrosoft Office 365\nIntermediate Knowledge:\n•\tC++\n•\tSQL\n•\tWindows Operating System\nBasic Knowledge:\n•\tUNIX\n•\tCloud Services\n•\tPower BI\n\u2003\nAchievements\n•\tHuawei ICT Competition Cloud Track 3rd Place\n•\tYear 1 Semester 2 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tYear 2 Semester 1 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tYear 1 Semester 1 Director List, Nanyang Polytechnic\n•\tYear 1 Semester 2 Director List, Nanyang Polytechnic\n•\tYear 2 Semester 1 Director List, Nanyang Polytechnic\n•\tEdusave Certificate of Academic Achievement 2023, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tCertificate of Completion, Literacy in AI, AI Singapore\n•\tCertificate of Completion, Foundations in AI, AI Singapore\n•\tCertificate of Completion, Python for Everybody, University of Michigan, Coursera\nProjects\n•\t“Computer Vision for Automated Assembly and Disassembly Manufacturing Plants” (Y2S2)\no\tConducted an in-depth literature review on plausible Computer Vision models for various tasks -- Anomaly Detection, Object Detection, and Object Segmentation – applicable to be used by Assembly/Disassembly robots.\no\tCollected and prepared datasets for model training using labelling applications.\no\tUsed fully customized Python Kera’s models and fine-tuned pre-trained models.\no\tCreated and deployed a production Web-Based AI application inclusive of all features developed and proper data pipelining.\n•\t“Service Outlet Location Recommendation” Project (Y2S1)\no\tFollowed CRISP-DM Methodology.\no\tDetermined business problems, objectives, and situation (Business Understanding)\no\tLed brainstorming sessions to determine the best factors for an outlet location.\no\tPerformed data preprocessing (Cleaning, Processing and Transformation) and analysis of disparate data sources using Python.\no\tLeveraged machine learning algorithms for analysis.\no\tPresented analysis and findings to stakeholders using intuitively designed dashboards.\n•\t“Oyster Mushroom Growth Analysis” Project (Y2S1)\no\tFormulated the project’s timeline and expected deliverables.\no\tCoordinated team members' tasks and responsibilities.\no\tMade use of Internet of Things (IoT) sensors and actuators to monitor and control the environment of oyster mushrooms remotely.\no\tCarried out statistical analysis on data collected from IoT sensors.\n•\tEngineering Exploration Project, “Bee Integration into Commercial Urban Farms” Project (Y1S2)\no\tReceived Certificate of Excellence\no\tGenerated innovative solutions to solve urban farms' inability to grow pollinator-dependent crops.\no\tSpearheaded group literature ...

# %%
own_resume_subset = own_resume[10: 200]
own_resume_subset
# Out:
# 'g Jia Shuo\nEmail: 222978d@mymail.nyp.edu.sg\nHandphone: 9777 1234\nLinkedIn: https://www.linkedin.com/in/js-chong-30766b273\nNationality: Singaporean\nLanguages Known: English and Chinese\nAbout '

# %%
new_database = pandas.concat([test_df, pandas.Series([own_resume], name='Resume')])
print(new_database.tail(1).values)
# Out:
# [[nan
#   "Name: Chong Jia Shuo\nEmail: 222978d@mymail.nyp.edu.sg\nHandphone: 9777 1234\nLinkedIn: https://www.linkedin.com/in/js-chong-30766b273\nNationality: Singaporean\nLanguages Known: English and Chinese\nAbout Me\nAs an individual who has developed a strong appreciation and passion for Artificial Intelligence (AI) during my study at NYP, I have actively engaged in independent, self-directed learning. I have taught myself various programming languages and fundamental theories of AI (Probability & Calculus, etc.). Currently, I am looking to add value to an organisation by using my knowledge and expertise to develop various AI models and algorithms, as well as share these outcomes with multiple stakeholders.\nEducation\n•\t‘O’ Level Graduate, Chung Cheng High School (Yishun)\no\tELR2B2 Nett 7\n•\tDiploma in AI and Data Engineering, Nanyang Polytechnic, Singapore, Year 2\no\tGPA 4.0\no\tRelevant Distinctions in:\n\uf0a7\tProgramming\n\uf0a7\tData Preparation & Visualization\n\uf0a7\tData Management\n\uf0a7\tMachine Learning\n\uf0a7\tCloud Computing & Platform\n\uf0a7\tData Engineering Project\n\uf0a7\tAnalytical Geometry (Diploma Plus Module)\n\uf0a7\tApplied Calculus (Diploma Plus Module)\nRelevant Skills\nProficient Skills:\n•\tPython\no\tScientific Libraries, i.e., NumPy and Pandas\n•\tMicrosoft Office 365\nIntermediate Knowledge:\n•\tC++\n•\tSQL\n•\tWindows Operating System\nBasic Knowledge:\n•\tUNIX\n•\tCloud Services\n•\tPower BI\n\u2003\nAchievements\n•\tHuawei ICT Competition Cloud Track 3rd Place\n•\tYear 1 Semester 2 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tYear 2 Semester 1 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tYear 1 Semester 1 Director List, Nanyang Polytechnic\n•\tYear 1 Semester 2 Director List, Nanyang Polytechnic\n•\tYear 2 Semester 1 Director List, Nanyang Polytechnic\n•\tEdusave Certificate of Academic Achievement 2023, Diploma in AI and Data Engineering, Nanyang Polytechnic\n•\tCertificate of Completion, Literacy in AI, AI Singapore\n•\tCertificate of Completion, Foundations in AI, AI Singapore\n•\tCertificate of Completion, Python for Everybody, University of Michigan, Coursera\nProjects\n•\t“Computer Vision for Automated Assembly and Disassembly Manufacturing Plants” (Y2S2)\no\tConducted an in-depth literature review on plausible Computer Vision models for various tasks -- Anomaly Detection, Object Detection, and Object Segmentation – applicable to be used by Assembly/Disassembly robots.\no\tCollected and prepared datasets for model training using labelling applications.\no\tUsed fully customized Python Kera’s models and fine-tuned pre-trained models.\no\tCreated and deployed a production Web-Based AI application inclusive of all features developed and proper data pipelining.\n•\t“Service Outlet Location Recommendation” Project (Y2S1)\no\tFollowed CRISP-DM Methodology.\no\tDetermined business problems, objectives, and situation (Business Understanding)\no\tLed brainstorming sessions to determine the best factors for an outlet location.\no\tPerformed data preprocessing (Cleaning, Processing and Transformation) and analysis of disparate data sources using Python.\no\tLeveraged machine learning algorithms for analysis.\no\tPresented analysis and findings to stakeholders using intuitively designed dashboards.\n•\t“Oyster Mushroom Growth Analysis” Project (Y2S1)\no\tFormulated the project’s timeline and expected deliverables.\no\tCoordinated team members' tasks and responsibilities.\no\tMade use of Internet of Things (IoT) sensors and actuators to monitor and control the environment of oyster mushrooms remotely.\no\tCarried out statistical analysis on data collected from IoT sensors.\n•\tEngineering Exploration Project, “Bee Integration into Commercial Urban Farms” Project (Y1S2)\no\tReceived Certificate of Excellence\no\tGenerated innovative solutions to solve urban farms' inability to grow pollinator-dependent crops.\no\tSpearheaded group literatu ...

# %%
new_database.tail(3)
# Out:
#             Category                                             Resume
# 30  DotNet Developer  participate intra college cricket competition ...
# 31      Data Science  skill program language python panda numpy scip...
# 0                NaN  Name: Chong Jia Shuo\nEmail: 222978d@mymail.ny...

# %%
result = retrieval(own_resume_subset, new_database, tfidf_vectorizer)
print(result)
# Out:
# Name: Chong Jia Shuo
# Email: 222978d@mymail.nyp.edu.sg
# Handphone: 9777 1234
# LinkedIn: https://www.linkedin.com/in/js-chong-30766b273
# Nationality: Singaporean
# Languages Known: English and Chinese
# About Me
# As an individual who has developed a strong appreciation and passion for Artificial Intelligence (AI) during my study at NYP, I have actively engaged in independent, self-directed learning. I have taught myself various programming languages and fundamental theories of AI (Probability & Calculus, etc.). Currently, I am looking to add value to an organisation by using my knowledge and expertise to develop various AI models and algorithms, as well as share these outcomes with multiple stakeholders.
# Education
# •	‘O’ Level Graduate, Chung Cheng High School (Yishun)
# o	ELR2B2 Nett 7
# •	Diploma in AI and Data Engineering, Nanyang Polytechnic, Singapore, Year 2
# o	GPA 4.0
# o	Relevant Distinctions in:
# 	Programming
# 	Data Preparation & Visualization
# 	Data Management
# 	Machine Learning
# 	Cloud Computing & Platform
# 	Data Engineering Project
# 	Analytical Geometry (Diploma Plus Module)
# 	Applied Calculus (Diploma Plus Module)
# Relevant Skills
# Proficient Skills:
# •	Python
# o	Scientific Libraries, i.e., NumPy and Pandas
# •	Microsoft Office 365
# Intermediate Knowledge:
# •	C++
# •	SQL
# •	Windows Operating System
# Basic Knowledge:
# •	UNIX
# •	Cloud Services
# •	Power BI
#
# Achievements
# •	Huawei ICT Competition Cloud Track 3rd Place
# •	Year 1 Semester 2 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Year 2 Semester 1 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Year 1 Semester 1 Director List, Nanyang Polytechnic
# •	Year 1 Semester 2 Director List, Nanyang Polytechnic
# •	Year 2 Semester 1 Director List, Nanyang Polytechnic
# •	Edusave Certificate of Academic Achievement 2023, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Certificate of Completion, Literacy in AI, AI Singapore
# •	Certificate of Completion, Foundations in AI, AI Singapore
# •	Certificate of Completion, Python for Everybody, University of Michigan, Coursera
# Projects
# •	“Computer Vision for Automated Assembly and Disassembly Manufacturing Plants” (Y2S2)
# o	Conducted an in-depth literature review on plausible Computer Vision models for various tasks -- Anomaly Detection, Object Detection, and Object Segmentation – applicable to be used by Assembly/Disassembly robots.
# o	Collected and prepared datasets for model training using labelling applications.
# o	Used fully customized Python Kera’s models and fine-tuned pre-trained models.
# o	Created and deployed a production Web-Based AI application inclusive of all features developed and proper data pipelining.
# •	“Service Outlet Location Recommendation” Project (Y2S1)
# o	Followed CRISP-DM Methodology.
# o	Determined business problems, objectives, and situation (Business Understanding)
# o	Led brainstorming sessions to determine the best factors for an outlet location.
# o	Performed data preprocessing (Cleaning, Processing and Transformation) and analysis of disparate data sources using Python.
# o	Leveraged machine learning algorithms for analysis.
# o	Presented analysis and findings to stakeholders using intuitively designed dashboards.
# •	“Oyster Mushroom Growth Analysis” Project (Y2S1)
# o	Formulated the project’s timeline and expected deliverables.
# o	Coordinated team members' tasks and responsibilities.
# o	Made use of Internet of Things (IoT) sensors and actuators to monitor and control the environment of oyster mushrooms remotely.
# o	Carried out statistical analysis on data collected from IoT sensors.
# •	Engineering Exploration Project, “Bee Integration into Commercial Urban Farms” Project (Y1S2)
# o	Received Certificate of Excellence
# o	Generated innovative solutions to solve urban farms' inability to grow pollinator-dependent crops.
# o	Spearheaded group literature review.
# o	Created a Functional Prototype using wireless data transfer technology: MQTT.
# Hobbies
# •	Programming
# •	Classical Piano
# •	Reading (Non-Fiction)

# %%
query = '''
statistical analysis
'''

# %%
result = retrieval(query, new_database, tfidf_vectorizer)
print(result)
# Out:
# Name: Chong Jia Shuo
# Email: 222978d@mymail.nyp.edu.sg
# Handphone: 9777 1234
# LinkedIn: https://www.linkedin.com/in/js-chong-30766b273
# Nationality: Singaporean
# Languages Known: English and Chinese
# About Me
# As an individual who has developed a strong appreciation and passion for Artificial Intelligence (AI) during my study at NYP, I have actively engaged in independent, self-directed learning. I have taught myself various programming languages and fundamental theories of AI (Probability & Calculus, etc.). Currently, I am looking to add value to an organisation by using my knowledge and expertise to develop various AI models and algorithms, as well as share these outcomes with multiple stakeholders.
# Education
# •	‘O’ Level Graduate, Chung Cheng High School (Yishun)
# o	ELR2B2 Nett 7
# •	Diploma in AI and Data Engineering, Nanyang Polytechnic, Singapore, Year 2
# o	GPA 4.0
# o	Relevant Distinctions in:
# 	Programming
# 	Data Preparation & Visualization
# 	Data Management
# 	Machine Learning
# 	Cloud Computing & Platform
# 	Data Engineering Project
# 	Analytical Geometry (Diploma Plus Module)
# 	Applied Calculus (Diploma Plus Module)
# Relevant Skills
# Proficient Skills:
# •	Python
# o	Scientific Libraries, i.e., NumPy and Pandas
# •	Microsoft Office 365
# Intermediate Knowledge:
# •	C++
# •	SQL
# •	Windows Operating System
# Basic Knowledge:
# •	UNIX
# •	Cloud Services
# •	Power BI
#
# Achievements
# •	Huawei ICT Competition Cloud Track 3rd Place
# •	Year 1 Semester 2 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Year 2 Semester 1 Top Student, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Year 1 Semester 1 Director List, Nanyang Polytechnic
# •	Year 1 Semester 2 Director List, Nanyang Polytechnic
# •	Year 2 Semester 1 Director List, Nanyang Polytechnic
# •	Edusave Certificate of Academic Achievement 2023, Diploma in AI and Data Engineering, Nanyang Polytechnic
# •	Certificate of Completion, Literacy in AI, AI Singapore
# •	Certificate of Completion, Foundations in AI, AI Singapore
# •	Certificate of Completion, Python for Everybody, University of Michigan, Coursera
# Projects
# •	“Computer Vision for Automated Assembly and Disassembly Manufacturing Plants” (Y2S2)
# o	Conducted an in-depth literature review on plausible Computer Vision models for various tasks -- Anomaly Detection, Object Detection, and Object Segmentation – applicable to be used by Assembly/Disassembly robots.
# o	Collected and prepared datasets for model training using labelling applications.
# o	Used fully customized Python Kera’s models and fine-tuned pre-trained models.
# o	Created and deployed a production Web-Based AI application inclusive of all features developed and proper data pipelining.
# •	“Service Outlet Location Recommendation” Project (Y2S1)
# o	Followed CRISP-DM Methodology.
# o	Determined business problems, objectives, and situation (Business Understanding)
# o	Led brainstorming sessions to determine the best factors for an outlet location.
# o	Performed data preprocessing (Cleaning, Processing and Transformation) and analysis of disparate data sources using Python.
# o	Leveraged machine learning algorithms for analysis.
# o	Presented analysis and findings to stakeholders using intuitively designed dashboards.
# •	“Oyster Mushroom Growth Analysis” Project (Y2S1)
# o	Formulated the project’s timeline and expected deliverables.
# o	Coordinated team members' tasks and responsibilities.
# o	Made use of Internet of Things (IoT) sensors and actuators to monitor and control the environment of oyster mushrooms remotely.
# o	Carried out statistical analysis on data collected from IoT sensors.
# •	Engineering Exploration Project, “Bee Integration into Commercial Urban Farms” Project (Y1S2)
# o	Received Certificate of Excellence
# o	Generated innovative solutions to solve urban farms' inability to grow pollinator-dependent crops.
# o	Spearheaded group literature review.
# o	Created a Functional Prototype using wireless data transfer technology: MQTT.
# Hobbies
# •	Programming
# •	Classical Piano
# •	Reading (Non-Fiction)

# %% [markdown]
# ## Resume Classification

# %%
def classification(resume: str, database: pandas.DataFrame, vectorizer):
    test_vector = vectorizer.transform([resume])
    
    highest_similarity = 0
    highest_label = None
    for to_test, label in zip(database.Resume.values, database.Category.values):
        similarity = cosine_similarity(test_vector, vectorizer.transform([to_test]))
        if similarity > highest_similarity:
            highest_similarity = similarity
            highest_label = label
    
    return highest_label

# %%
num = 2
classification(test_resumes[num], train_df, tfidf_vectorizer)
print(test_labels[num])
# Out:
# HR

# %% [markdown]
# #### Evaluation

# %%
y_pred = test_resumes.apply(lambda x: classification(x, train_df, tfidf_vectorizer))
y_pred

#Compare new values with initial database train_df to find most similar label
# Out:
# 0         Automation Testing
# 1              ETL Developer
# 2                         HR
# 3                         HR
# 4             Civil Engineer
# 5     Electrical Engineering
# 6             Java Developer
# 7             Java Developer
# 8                         HR
# 9                   Database
# 10        Health and fitness
# 11           DevOps Engineer
# 12             Web Designing
# 13                    Hadoop
# 14              Data Science
# 15            Civil Engineer
# 16        Operations Manager
# 17                    Hadoop
# 18                  Advocate
# 19          Python Developer
# 20            Civil Engineer
# 21                Blockchain
# 22                       PMO
# 23                        HR
# 24                     Sales
# 25                   Testing
# 26              Data Science
# 27          DotNet Developer
# 28              Data Science
# 29              Data Science
# 30          DotNet Developer
# 31              Data Science
# Name: Resume, dtype: object

# %%
accuracy_score(test_labels, y_pred)
# Out:
# 0.84375

# %% [markdown]
# ## Resume Summarization

# %%
import cohere
co_client = cohere.Client('41ApJD1HzYGiYv7R3uKNNp8W4yK8UFlcyBcwRD68')

# %%
initial_context = 'This is a resume provided in a normalized format:\n'
resume_to_summarize = own_resume
task_to_complete = '\nIn summary:'

message = initial_context + resume_to_summarize + task_to_complete

# %%
response = co_client.chat(
    message,
    model="command",
    temperature=0
)

# %%
print(response.text)
# Out:
# Here is a resume summary:
#
# During his studies at Nanyang Polytechnic, Chong Jia Shuo developed a passion for Artificial Intelligence (AI). He is proficient in Python and well-versed in programming, data management, and machine learning. He also has experience with cloud computing and platform topics. With a Distinction in these subjects under his belt, he is equipped with the necessary skills to develop innovative AI models and algorithms.
#
# He is an independent learner who is also pursuing hobbies like programming and classical piano to augment his skills. He has also received multiple awards and certificates for excellence in his field, including third place in the Huawei ICT Competition Cloud Track. With his expertise and achievements, he is eager to contribute value to a company and facilitate the sharing of these outcomes with stakeholders.
#
# Chong is a motivated individual who is dedicated to solving problems and learning new skills. He is confident that his skills and experience make him a strong candidate for the position.

# %%
len(response.text)
# Out:
# 1046

# %%
len(own_resume)
# Out:
# 3986
