# %%
import numpy
import pandas
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score

# %%
resumes_df = pandas.read_csv('cleanedResumesTrain.csv')
resumes_df
# Out:
#              Category                                             Resume
# 0        Data Science  qwtnrvduof education detail may 2013 to may 20...
# 1        Data Science  qwtnrvduof area of interest deep learn control...
# 2        Data Science  skill r python sap hana tableau sap hana sql s...
# 3        Data Science  education detail mca ymcaust faridabad haryana...
# 4        Data Science  skill c basic iot python matlab data science m...
# ..                ...                                                ...
# 151           Testing  computer skill software knowledge m power poin...
# 152           Testing  good logical and analytical skill positive att...
# 153           Testing  personal skill quick learner eagerness to lear...
# 154   DevOps Engineer  core skill project program management agile sc...
# 155  Business Analyst  education detail february 2006 to february 200...
#
# [156 rows x 2 columns]

# %%
resumes = resumes_df.Resume.to_numpy()
resumes
# Out:
# array(['qwtnrvduof education detail may 2013 to may 2017 bbntgbqlmkke uit rgpv data scientist data scientist matelabs skill detail python exprience le than 1 year month statsmodels exprience 12 month aws exprience le than 1 year month machine learn exprience le than 1 year month sklearn exprience le than 1 year month scipy exprience le than 1 year month keras exprience le than 1 year monthscompany detail company matelabs description ml platform for business professional dummy and enthusiastsckekjofvwq 60 a koramangala 5th block achievement task behind sukh sagar bengaluru india develop and deployed auto preprocessing step of machine learn mainly miss value treatment outlier detection encode scaling feature selection and dimensionality reductionqunsobcudt deploy automate classification and regression modelrynoolxhuv b4600b146 reasearch and deploy the time series forecast model arima sarimax holt winter and prophetiqmadshiyn work on meta feature extract problemiszogerzlf implement a st
# ...

# %%
vectorizer = CountVectorizer()

# %%
vectorizer.fit(resumes)
# Out:
# CountVectorizer()

# %%
test_df = pandas.read_csv('cleanedResumesTest.csv')
test_df
# Out:
#                   Category                                             Resume
# 0                  Testing  skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 1            ETL Developer  skill set talend big data informatica power ce...
# 2                       HR  training in special education certificate cour...
# 3                       HR  education detail bba lovely professional unive...
# 4           Civil Engineer  computer knowledge drafting tool autocadbntgbq...
# 5   Electrical Engineering  education detail july 2016 to may 2019 be elec...
# 6            Web Designing  education detail bbntgbqlmkkcckekjofvwqa bache...
# 7           Java Developer  technicalskills springmvc hibernate jdbc java ...
# 8                       HR  education detail mba acn college of engineerin...
# 9                 Database  software skill rdbms m sql server 2000 2005 20...
# 10      Health and fitness  education detail january 2009 pbntgbqlmkkgckek...
# ...

# %%
test_resumes = test_df.Resume
test_resumes
# Out:
# 0     skill set o window xp 7 8 8bntgbqlmkk1 10 data...
# 1     skill set talend big data informatica power ce...
# 2     training in special education certificate cour...
# 3     education detail bba lovely professional unive...
# 4     computer knowledge drafting tool autocadbntgbq...
# 5     education detail july 2016 to may 2019 be elec...
# 6     education detail bbntgbqlmkkcckekjofvwqa bache...
# 7     technicalskills springmvc hibernate jdbc java ...
# 8     education detail mba acn college of engineerin...
# 9     software skill rdbms m sql server 2000 2005 20...
# 10    education detail january 2009 pbntgbqlmkkgckek...
# 11    skill visa b1 visa usa onsite visit to sweden ...
# 12    technical skill web technology angular j html5...
# 13    technical skill program language c c java bntg...
# 14    education detail bachelor s bachelor s commerc...
# 15    skill 1bntgbqlmkkautocad 2ckekjofvwqpro v 3qun...
# 16    education detail bca vinayaka mission universi...
# ...

# %%
test_labels = test_df.Category
test_labels
# Out:
# 0                    Testing
# 1              ETL Developer
# 2                         HR
# 3                         HR
# 4             Civil Engineer
# 5     Electrical Engineering
# 6              Web Designing
# 7             Java Developer
# 8                         HR
# 9                   Database
# 10        Health and fitness
# 11           DevOps Engineer
# 12             Web Designing
# 13                    Hadoop
# 14                     Sales
# 15            Civil Engineer
# 16        Operations Manager
# 17                    Hadoop
# 18                  Advocate
# 19          Python Developer
# 20            Civil Engineer
# 21                Blockchain
# 22                       PMO
# 23                        HR
# 24                     Sales
# 25                   Testing
# 26              Data Science
# 27          DotNet Developer
# 28                  Advocate
# 29             SAP Developer
# 30          DotNet Developer
# 31              Data Science
# ...

# %% [markdown]
# ## Manual

# %%
def retrieval(resume: str, database: pandas.DataFrame, vectorizer):
    test_vector = vectorizer.transform([resume])
    
    highest_similarity = 0
    highest_label = None
    for to_test, label in zip(database.Resume.values, database.Category.values):
        similarity = cosine_similarity(test_vector, vectorizer.transform([to_test]))
        if similarity > highest_similarity:
            highest_similarity = similarity
            highest_label = label
    
    return highest_label

# %%
num = 2
retrieval(test_resumes[num], resumes_df, vectorizer)
print(test_labels[num])
# Out:
# HR

# %%
y_pred = test_resumes.apply(lambda x: retrieval(x, resumes_df, vectorizer))
y_pred
# Out:
# 0            Automation Testing
# 1                 SAP Developer
# 2            Health and fitness
# 3                            HR
# 4                Civil Engineer
# 5        Electrical Engineering
# 6              DotNet Developer
# 7                Java Developer
# 8                            HR
# 9                      Database
# 10    Network Security Engineer
# 11           Health and fitness
# 12                         Arts
# 13                       Hadoop
# 14                 Data Science
# 15                         Arts
# 16             Business Analyst
# 17                       Hadoop
# 18                     Advocate
# 19                 Data Science
# 20             Business Analyst
# 21                   Blockchain
# 22                          PMO
# 23                      Testing
# 24                         Arts
# 25    Network Security Engineer
# 26                 Data Science
# 27              DevOps Engineer
# 28                 Data Science
# ...

# %%
accuracy_score(test_labels, y_pred)
# Out:
# 0.40625

# %% [markdown]
# ## Machine Learning
